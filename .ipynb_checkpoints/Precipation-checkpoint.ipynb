# %%
# %run PLT.py
from matplotlib import pyplot as plt
from matplotlib.dates import DateFormatter
import numpy as np
import xarray as xr
import pandas as pd
import scipy
from datetime import datetime, timedelta
import time
# import seaborn
import matplotlib.dates as mdates
import bottleneck as bn
import PyCO2SYS as pyco2
import gsw
import math
import netCDF4 as nc
import requests
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error

from importlib import reload
import warnings
warnings.filterwarnings('ignore')
# Out:
# C:\Users\georg\miniconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
import gspread
from df2gspread import df2gspread as d2g
from oauth2client.service_account import ServiceAccountCredentials

scope = [
   'https://spreadsheets.google.com/feeds',
         'https://www.googleapis.com/auth/drive']

# Name of our Service Account Key
google_key_file = 'servicecredentials.json'
credentials = ServiceAccountCredentials.from_json_keyfile_name(google_key_file, scope)
gc = gspread.authorize(credentials)

# Spreadsheet key
spreadsheet_key = '1uLRAvFDsTSfS-c45DiG-W6VMa8I1J7XD1O-pJA4fp10'

# Worksheet keys
wks_hydrocat620 = 'Hydrocat 620'
wks_hydrocat720 = 'Hydrocat 720'
wks_MV = 'MV'
wks_QP = 'QP'

#Opening the worksheet by using Worksheet ID
workbook = gc.open_by_key(spreadsheet_key)

## HYDROCAT 620
#Selecting which sheet to pulling the data
sheet = workbook.worksheet(wks_hydrocat620)
values = sheet.get_all_values()
hydrocat620 = pd.DataFrame(values[1:], columns = values[0])


## HYDROCAT 720
#Selecting which sheet to pulling the data
sheet = workbook.worksheet(wks_hydrocat720)
values = sheet.get_all_values()
hydrocat720 = pd.DataFrame(values[1:], columns = values[0])

## MV
#Selecting which sheet to pulling the data
sheet = workbook.worksheet(wks_MV)
values = sheet.get_all_values()
MV = pd.DataFrame(values[1:], columns = values[0])


## QP
#Selecting which sheet to pulling the data
sheet = workbook.worksheet(wks_QP)
values = sheet.get_all_values()
QP = pd.DataFrame(values[1:], columns = values[0])

# %%
for k in hydrocat620.keys():
    if k == 'DateTime' or k == 'time':
        hydrocat620[k] = pd.to_datetime(hydrocat620[k],format='ISO8601')
    else:
        hydrocat620[k] = pd.to_numeric(hydrocat620[k])

for k in hydrocat720.keys():
    if k == 'DateTime' or k == 'time':
        hydrocat720[k] = pd.to_datetime(hydrocat720[k],format='ISO8601')
    else:
        hydrocat720[k] = pd.to_numeric(hydrocat720[k])
        
for k in QP.keys():
    if k == 'DateTime' or k == 'time':
        QP[k] = pd.to_datetime(QP[k],format='ISO8601')
    else:
        QP[k] = pd.to_numeric(QP[k])
        
for k in MV.keys():
    if k == 'DateTime' or k == 'time':
        MV[k] = pd.to_datetime(MV[k],format='ISO8601')
    else:
        MV[k] = pd.to_numeric(MV[k])

# %% [markdown]
#  # metdata precipitation

# %%
MetData = PLT.get_buoy('2021-11-01', '2023-06-01','PLT','MetData')

# %%
df = pd.DataFrame (MetData)

# %%
NOAATides = pd.read_csv('/Users/georg/Downloads/NOAA_tides_2022_hourly_MHHW.csv')

# %%
NOAATides
# Out:
#             Date Time (GMT)  Predicted (ft) Preliminary (ft)  Verified (ft)
# 0       1/1/2022       0:00          -1.013                -          -0.16
# 1       1/1/2022       1:00          -2.108                -          -1.28
# 2       1/1/2022       2:00          -3.368                -          -2.44
# 3       1/1/2022       3:00          -4.331                -          -3.31
# 4       1/1/2022       4:00          -4.687                -          -3.61
# ...          ...        ...             ...              ...            ...
# 8755  12/31/2022      19:00          -1.049                -          -0.92
# 8756  12/31/2022      20:00          -0.903                -          -0.50
# 8757  12/31/2022      21:00          -1.308                -          -0.79
# 8758  12/31/2022      22:00          -2.086                -          -1.56
# 8759  12/31/2022      23:00          -2.944                -          -2.52
#
# [8760 rows x 5 columns]

# %%
NOAATides = NOAATides.drop('Preliminary (ft)', axis=1)

for i in NOAATides.keys():
    if i == 'Date' or i == 'Time (GMT)':
        NOAATides[i] = pd.to_datetime(NOAATides[i])
    else:
        NOAATides[i] = pd.to_numeric(NOAATides[i])

# %%
hydrocat620
# Out:
#                      DateTime                    time  ordinal_time  \
# 0     2022-01-20 11:31:15.400 2022-01-20 11:31:15.400      738175.0
# 1     2022-01-20 11:46:15.200 2022-01-20 11:46:15.200      738175.0
# 2     2022-01-20 13:16:15.400 2022-01-20 13:16:15.400      738175.0
# 3     2022-01-20 13:31:15.200 2022-01-20 13:31:15.200      738175.0
# 4     2022-01-20 13:46:15.400 2022-01-20 13:46:15.400      738175.0
# ...                       ...                     ...           ...
# 32805 2023-05-06 22:46:29.200 2023-05-06 22:46:29.200      738646.0
# 32806 2023-05-06 23:01:29.200 2023-05-06 23:01:29.200      738646.0
# 32807 2023-05-06 23:16:29.200 2023-05-06 23:16:29.200      738646.0
# 32808 2023-05-06 23:31:29.000 2023-05-06 23:31:29.000      738646.0
# 32809 2023-05-06 23:46:29.000 2023-05-06 23:46:29.000      738646.0
#
#        hydrocatTemperature  hydrocatDissOxygen  hydrocatSalinity  pH total  \
# 0                   2.7870              11.214           30.3511  8.120364
# 1                   2.8096              11.291           30.3408  8.120305
# 2                   2.6755              11.517           30.0325  8.119959
# 3                   2.5723              11.674           29.9040  8.119898
# 4                   2.6616              11.710           29.9747  8.109874
# ...                    ...                 ...               ...       ...
# 32805              13.7498               8.936           25.6888  7.984200
# 32806              13.5934               8.941           25.7091  8.004486
# 32807              13.7830               8.939           25.6966  7.994154
# 32808              13.7271               8.871           25.7682  7.974337
# 32809              13.6768               8.771           25.8686  7.974548
#
#        hydrocatFluorescence    offset  adjusted_ph  offset temp  \
# 0                    13.487  0.000000     8.120364     0.511002
# 1                    15.119  0.000000     8.120305     0.509171
# 2                    13.664  0.000000     8.119959     0.520112
# 3                    15.239  0.000000     8.119898     0.528660
# 4                    13.259  0.000000     8.109874     0.521257
# ...                     ...       ...          ...          ...
# 32805                 0.098  0.124405     7.859795     0.000000
# 32806                 0.097  0.124405     7.880081     0.000000
# 32807                 0.096  0.124405     7.869749     0.000000
# 32808                 0.096  0.124405     7.849932     0.000000
# 32809                 0.095  0.124405     7.850143     0.000000
#
#        adjusted_ph temp
# 0              7.609362
# 1              7.611134
# 2              7.599846
# 3              7.591237
# 4              7.588617
# ...                 ...
# 32805          7.984200
# 32806          8.004486
# 32807          7.994154
# 32808          7.974337
# 32809          7.974548
#
# [32810 rows x 12 columns]

# %%
fig,ax = plt.subplots(figsize = [20,20])

ax.plot(hydrocat620['DateTime'].to_numpy(), hydrocat620['hydrocatSalinity'].to_numpy(), color = '#FFBBFF', marker='D', label = 'hydrocat 620 sensor') 

ax.set_ylabel('Salinity',color = '#FFBBFF', fontsize = 12)
ax.set_xlabel('Date Time', fontsize=12)
ax.xaxis.set_major_locator(mdates.MonthLocator(interval=1))
ax.tick_params('x',labelsize = 12, labelrotation = 90)
ax.tick_params('y',labelsize = 12)
ax.legend(loc = 'lower left', fontsize = 14)

ax1 = ax.twinx() 
ax1.plot(NOAATides['Date'].to_numpy(), NOAATides['Verified (ft)'].to_numpy(), color = '#76EEC6',marker = 'D', label ='NOAA Tides')
ax1.set_ylabel('Tides Height',c = '#76EEC6', fontsize = 12)

ax1.xaxis.set_major_locator(mdates.MonthLocator(interval=1))
ax1.tick_params('x',labelsize = 12, labelrotation = 90)
ax1.tick_params('y',labelsize = 12)
ax1.legend(loc = 'lower left', fontsize = 14)

# %% [markdown]
# ## zoomed in

# %%
fig,ax = plt.subplots(figsize = [20,20])

ax.plot(hydrocat620['DateTime'].to_numpy(), hydrocat620['hydrocatSalinity'].to_numpy(), color = '#FFBBFF', marker='D', label = 'hydrocat 620 sensor') 

ax.set_ylabel('Salinity',color = '#FFBBFF', fontsize = 12)
ax.set_xlabel('Date Time', fontsize=12)
ax.xaxis.set_major_locator(mdates.MonthLocator(interval=1))
ax.tick_params('x',labelsize = 12, labelrotation = 90)
ax.tick_params('y',labelsize = 12)
ax.legend(loc = 'lower left', fontsize = 14)
plt.ylim([25,32])

#Secondary y axis
ax1 = ax.twinx() 
ax1.plot(NOAATides['Date'].to_numpy(), NOAATides['Verified (ft)'].to_numpy(), color = '#76EEC6',marker = 'D', label ='NOAA Tides')
ax1.set_ylabel('Tides Height',c = '#76EEC6', fontsize = 12)

ax1.xaxis.set_major_locator(mdates.MonthLocator(interval=1))
ax1.tick_params('x',labelsize = 12, labelrotation = 90)
ax1.tick_params('y',labelsize = 12)
ax1.legend(loc = 'lower left', fontsize = 14)

ax.set_zorder(ax1.get_zorder() + 1)
ax.patch.set_visible(False)

# %% [markdown]
# ## zoomed in looking at 6 month period

# %%
fig,ax = plt.subplots(figsize = [20,20])

ax.plot(hydrocat620['DateTime'].to_numpy(), hydrocat620['hydrocatSalinity'].to_numpy(), color = '#FFBBFF', marker='D', label = 'hydrocat 620 sensor') 

ax.set_ylabel('Salinity',color = '#FFBBFF', fontsize = 12)
ax.set_xlabel('Date Time', fontsize=12)
ax.xaxis.set_major_locator(mdates.MonthLocator(interval=1))
ax.tick_params('x',labelsize = 12, labelrotation = 90)
ax.tick_params('y',labelsize = 12)
ax.legend(loc = 'lower left', fontsize = 14)
plt.ylim([25,32])

#Secondary y axis
ax1 = ax.twinx() 
ax1.plot(NOAATides['Date'].to_numpy(), NOAATides['Verified (ft)'].to_numpy(), color = '#76EEC6',marker = 'D', label ='NOAA Tides')
ax1.set_ylabel('Tides Height',c = '#76EEC6', fontsize = 12)

ax1.xaxis.set_major_locator(mdates.MonthLocator(interval=1))
ax1.tick_params('x',labelsize = 12, labelrotation = 90)
ax1.tick_params('y',labelsize = 12)
ax1.legend(loc = 'lower left', fontsize = 14)
start_date =pd.to_datetime('2022-01-01')
end_date = pd.to_datetime('2022-07-01')
plt.xlim(start_date, end_date)
ax.set_zorder(ax1.get_zorder() + 1)
ax.patch.set_visible(False)

# %% [markdown]
# # pH changes in relation to tide over time

# %%
fig,ax1 = plt.subplots(figsize = [20,20])

ax1.plot(hydrocat620['DateTime'].to_numpy(), hydrocat620['adjusted_ph temp'].to_numpy(), color = 'crimson', marker='D', label = 'hydrocat 620 sensor',zorder = 3) 
ax1.set_ylabel('pH', fontsize = 12)
ax1.set_xlabel('Date Time', fontsize=12)
ax1.xaxis.set_major_locator(mdates.MonthLocator(interval=1))
ax1.tick_params('x',labelsize = 12, labelrotation = 45)
ax1.tick_params('y',labelsize = 12)
ax1.legend(loc = 'lower left', fontsize = 14)

ax2 = ax1.twinx() 
ax2.plot(NOAATides['Date'].to_numpy(), NOAATides['Verified (ft)'].to_numpy(), color = '#76EEC6',marker = 'D', label ='NOAA Tides',zorder = 0)
ax2.set_ylabel('Tides Height', fontsize = 12)


# ax2.yaxis.set_label_coords(1,.5)

# # Set labels for the top and bottom of the secondary y-axis
# ax2.text(4, 4.05, 'high tide', transform=ax2.transAxes, ha='right')
# ax2.text(-4, -4.1, 'low tide', transform=ax2.transAxes, ha='right')
   

ax2.xaxis.set_major_locator(mdates.MonthLocator(interval=1))
ax2.tick_params('x',labelsize = 12, labelrotation = 45)
ax2.tick_params('y',labelsize = 12)
ax2.legend(loc = 'lower right', fontsize = 14)
 

    
ax1.set_zorder(ax2.get_zorder() + 1)
ax1.patch.set_visible(False)

# %% [markdown]
# ## Yearly tide changes

# %%
fig,ax1 = plt.subplots(figsize = [20,20])

ax1.plot(hydrocat620['DateTime'].to_numpy(), hydrocat620['adjusted_ph temp'].to_numpy(), color = 'crimson', marker='D', label = 'hydrocat 620 sensor',zorder = 3) 
ax1.set_ylabel('pH',color = 'crimson', fontsize = 12)
ax1.set_xlabel('Date Time', fontsize=12)
ax1.xaxis.set_major_locator(mdates.MonthLocator(interval=1))
ax1.tick_params('x',labelsize = 12, labelrotation = 90)
ax1.tick_params('y',labelsize = 12)
ax1.legend(loc = 'lower left', fontsize = 14)

ax2 = ax1.twinx() 
ax2.plot(NOAATides['Date'].to_numpy(), NOAATides['Verified (ft)'].to_numpy(), color = '#76EEC6',marker = 'D', label ='NOAA Tides',zorder = 0)
ax2.set_ylabel('Tides Height',c = '#76EEC6', fontsize = 12)

ax2.xaxis.set_major_locator(mdates.MonthLocator(interval=1))
ax2.tick_params('x',labelsize = 12, labelrotation = 90)
ax2.tick_params('y',labelsize = 12)
ax2.legend(loc = 'lower right', fontsize = 14)
 
ax1.set_zorder(ax2.get_zorder() + 1)
ax1.patch.set_visible(False)

start_date =pd.to_datetime('2022-01-01')
end_date = pd.to_datetime('2023-01-01')
plt.xlim(start_date, end_date)
# Out:
# (18993.0, 19358.0)

# %% [markdown]
# ## changes in a 6 month time spand

# %%
fig,ax1 = plt.subplots(figsize = [20,20])

ax1.plot(hydrocat620['DateTime'].to_numpy(), hydrocat620['adjusted_ph temp'].to_numpy(), color = 'crimson', marker='D', label = 'hydrocat 620 sensor',zorder = 3) 
ax1.set_ylabel('pH',color = 'crimson', fontsize = 12)
ax1.set_xlabel('Date Time', fontsize=12)
ax1.xaxis.set_major_locator(mdates.MonthLocator(interval=1))
ax1.tick_params('x',labelsize = 12, labelrotation = 90)
ax1.tick_params('y',labelsize = 12)
ax1.legend(loc = 'lower left', fontsize = 14)
plt.ylim([7,8])
ax2 = ax1.twinx() 
ax2.plot(NOAATides['Date'].to_numpy(), NOAATides['Verified (ft)'].to_numpy(), color = '#76EEC6',marker = 'D', label ='NOAA Tides',zorder = 0)
ax2.set_ylabel('Tides Height',c = '#76EEC6', fontsize = 12)

ax2.xaxis.set_major_locator(mdates.MonthLocator(interval=1))
ax2.tick_params('x',labelsize = 12, labelrotation = 90)
ax2.tick_params('y',labelsize = 12)
ax2.legend(loc = 'lower right', fontsize = 14)
 
ax1.set_zorder(ax2.get_zorder() + 1)
ax1.patch.set_visible(False)

start_date =pd.to_datetime('2022-01-01')
end_date = pd.to_datetime('2022-07-01')
plt.xlim(start_date, end_date)
# Out:
# (18993.0, 19174.0)

# %% [markdown]
# ## changes in a month and some change bc jan didn't have a lot of data(winter)

# %%
fig,ax1 = plt.subplots(figsize = [20,20])

ax1.plot(hydrocat620['DateTime'].to_numpy(), hydrocat620['adjusted_ph temp'].to_numpy(), color = 'crimson', marker='D', label = 'hydrocat 620 sensor',zorder = 3) 
ax1.set_ylabel('pH',color = 'crimson', fontsize = 12)
ax1.set_xlabel('Date Time', fontsize=12)
ax1.xaxis.set_major_locator(mdates.MonthLocator(interval=1))
ax1.tick_params('x',labelsize = 12, labelrotation = 90)
ax1.tick_params('y',labelsize = 12)
ax1.legend(loc = 'lower left', fontsize = 14)
plt.ylim([7.4,8])
ax2 = ax1.twinx() 
ax2.plot(NOAATides['Date'].to_numpy(), NOAATides['Verified (ft)'].to_numpy(), color = '#76EEC6',marker = 'D', label ='NOAA Tides',zorder = 0)
ax2.set_ylabel('Tides Height',c = '#76EEC6', fontsize = 12)

ax2.xaxis.set_major_locator(mdates.MonthLocator(interval=1))
ax2.tick_params('x',labelsize = 12, labelrotation = 90)
ax2.tick_params('y',labelsize = 12)
ax2.legend(loc = 'lower right', fontsize = 14)
 
ax1.set_zorder(ax2.get_zorder() + 1)
ax1.patch.set_visible(False)

start_date =pd.to_datetime('2022-01-01')
end_date = pd.to_datetime('2022-03-01')
plt.xlim(start_date, end_date)
# Out:
# (18993.0, 19052.0)

# %% [markdown]
# ## Changes in a month (summer)

# %%
fig,ax1 = plt.subplots(figsize = [20,20])

ax1.plot(hydrocat620['DateTime'].to_numpy(), hydrocat620['adjusted_ph temp'].to_numpy(), color = 'crimson', marker='D', label = 'hydrocat 620 sensor',zorder = 3) 
ax1.set_ylabel('pH',color = 'crimson', fontsize = 12)
ax1.set_xlabel('Date Time', fontsize=12)
ax1.xaxis.set_major_locator(mdates.MonthLocator(interval=1))
ax1.tick_params('x',labelsize = 12, labelrotation = 90)
ax1.tick_params('y',labelsize = 12)
ax1.legend(loc = 'lower left', fontsize = 14)
plt.ylim([7.5,7.9])
ax2 = ax1.twinx() 
ax2.plot(NOAATides['Date'].to_numpy(), NOAATides['Verified (ft)'].to_numpy(), color = '#76EEC6',marker = 'D', label ='NOAA Tides',zorder = 0)
ax2.set_ylabel('Tides Height',c = '#76EEC6', fontsize = 12)

ax2.xaxis.set_major_locator(mdates.MonthLocator(interval=1))
ax2.tick_params('x',labelsize = 12, labelrotation = 90)
ax2.tick_params('y',labelsize = 12)
ax2.legend(loc = 'lower right', fontsize = 14)
 
ax1.set_zorder(ax2.get_zorder() + 1)
ax1.patch.set_visible(False)

start_date =pd.to_datetime('2022-08-01')
end_date = pd.to_datetime('2022-09-01')
plt.xlim(start_date, end_date)
# Out:
# (19205.0, 19236.0)

# %% [markdown]
# ## Changes in a day

# %%
fig,ax1 = plt.subplots(figsize = [20,20])

ax1.plot(hydrocat620['DateTime'].to_numpy(), hydrocat620['adjusted_ph temp'].to_numpy(), color = 'crimson', marker='D', label = 'hydrocat 620 sensor',zorder = 3) 
ax1.set_ylabel('pH',color = 'crimson', fontsize = 12)
ax1.set_xlabel('Date Time', fontsize=12)
ax1.xaxis.set_major_locator(mdates.MonthLocator(interval=1))
ax1.tick_params('x',labelsize = 12, labelrotation = 90)
ax1.tick_params('y',labelsize = 12)
ax1.legend(loc = 'lower left', fontsize = 14)

ax2 = ax1.twinx() 
ax2.plot(NOAATides['Date'].to_numpy(), NOAATides['Verified (ft)'].to_numpy(), color = '#76EEC6',marker = 'D', label ='NOAA Tides',zorder = 0)
ax2.set_ylabel('Tides Height',c = '#76EEC6', fontsize = 12)

ax2.xaxis.set_major_locator(mdates.MonthLocator(interval=1))
ax2.tick_params('x',labelsize = 12, labelrotation = 90)
ax2.tick_params('y',labelsize = 12)
ax2.legend(loc = 'lower right', fontsize = 14)
 
ax1.set_zorder(ax2.get_zorder() + 1)
ax1.patch.set_visible(False)

start_date =pd.to_datetime('2022-08-01')
end_date = pd.to_datetime('2022-08-15')
plt.xlim(start_date, end_date)
# Out:
# (19205.0, 19219.0)
