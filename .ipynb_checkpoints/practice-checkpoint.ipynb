# %%
import PyCO2SYS as pyco2
import pandas as pd 
import gspread
import numpy as np 
import xarray as xr 
import re
import requests
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
from sklearn import datasets
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from matplotlib.dates import DateFormatter
from datetime import datetime, timedelta
import matplotlib.dates as mdates
import time
import warnings
warnings.filterwarnings('ignore')
import math
import gsw
import matplotlib as plt
from matplotlib import pyplot as plt
from matplotlib.ticker import (MultipleLocator, FormatStrFormatter,
                               AutoMinorLocator)

# %%
# %run PLT.py

# %%
df = PLT.get_hydrocat('2022-01-01', '2022-12-30', 'PLT')
df
# Out:
#                         TmStamp        hydrocatStart  hydrocatTemperature  \
# 0      2022-01-04T09:31:15.400Z                 None               6.5078
# 1      2022-01-04T10:46:15.400Z                 None               6.3631
# 2      2022-01-04T11:01:15.200Z                 None               6.3063
# 3      2022-01-04T11:16:15.200Z                 None               6.2367
# 4      2022-01-04T11:31:15.200Z                 None               6.2593
# ...                         ...                  ...                  ...
# 24621  2022-12-29T22:46:29.000Z  12/29/2022 22:45:00               3.9276
# 24622  2022-12-29T23:01:29.000Z  12/29/2022 23:00:00               3.9210
# 24623  2022-12-29T23:16:29.000Z  12/29/2022 23:15:00               3.9183
# 24624  2022-12-29T23:31:29.000Z  12/29/2022 23:30:00               3.9342
# 24625  2022-12-29T23:46:29.000Z  12/29/2022 23:45:00               3.9737
#
#        hydrocatConductivity  hydrocatDissOxygen  hydrocatSalinity  \
# ...

# %%
import gspread
from df2gspread import df2gspread as d2g
from oauth2client.service_account import ServiceAccountCredentials

scope = [
   'https://spreadsheets.google.com/feeds',
         'https://www.googleapis.com/auth/drive']

# Name of our Service Account Key
google_key_file = 'servicecredentials.json'
credentials = ServiceAccountCredentials.from_json_keyfile_name(google_key_file, scope)
gc = gspread.authorize(credentials)

# %% [markdown]
# Pulling Bottle samples

# %%
spreadsheet_key = '17FFbtUuhUS4UtxB-OjKIP2wCYJoEAmaW6VaHQPcup9U'
wks_name = 'Sheet1'


#Opening the worksheet by using Worksheet ID
spreadsheet = gc.open_by_key(spreadsheet_key)
#Selecting which sheet to pulling the data
sheet = spreadsheet.worksheet(wks_name)

#Pulling the data and transform it to the data frame
values = sheet.get_all_values()
labdata = pd.DataFrame(values[1:], columns = values[0])
labdata.head()
# Out:
#                Sample          Time Location    depth TA Temp (degC)  \
# 0       PLT 4/28/22 A  4/28/22 7:30      PLT  surface           20.9
# 1       PLT 4/28/22 B  4/28/22 7:30      PLT  surface           20.9
# 2   PLT 5/9/22 surf A   5/9/22 7:30      PLT  surface           20.3
# 3   PLT 5/9/22 surf B   5/9/22 7:30      PLT  surface           20.3
# 4  PLT 5/22/22 bottom  5/22/22 7:30      PLT   bottom           20.9
#
#     TA (uM) DIC Temp (degC)    DIC (uM) Salinity
# 0  2078.825              22  1931.63783    29.48
# 1   2078.41              22  1931.62999    29.48
# 2   2075.47              22  1985.40452    29.42
# 3   2076.78              22  1955.71939    29.42
# 4  2138.395              22  1978.53868    30.62

# %%
df = labdata[['Sample', 'Time', 'Location', 'depth', 'TA Temp (degC)', 'TA (uM)',
       'DIC Temp (degC)', 'DIC (uM)', 'Salinity']]
df['TA (uM)'] = pd.to_numeric(df['TA (uM)'])
df['TA Temp (degC)'] = pd.to_numeric(df['TA Temp (degC)'])
df['DIC (uM)'] = pd.to_numeric(df['DIC (uM)'])
df['DIC Temp (degC)'] = pd.to_numeric(df['DIC Temp (degC)'])
df['Salinity'] = pd.to_numeric(df['Salinity'])
df["DateTime"] = pd.to_datetime(df["Time"])
df.head()
# Out:
#                Sample          Time Location    depth  TA Temp (degC)  \
# 0       PLT 4/28/22 A  4/28/22 7:30      PLT  surface            20.9
# 1       PLT 4/28/22 B  4/28/22 7:30      PLT  surface            20.9
# 2   PLT 5/9/22 surf A   5/9/22 7:30      PLT  surface            20.3
# 3   PLT 5/9/22 surf B   5/9/22 7:30      PLT  surface            20.3
# 4  PLT 5/22/22 bottom  5/22/22 7:30      PLT   bottom            20.9
#
#     TA (uM)  DIC Temp (degC)    DIC (uM)  Salinity            DateTime
# 0  2078.825             22.0  1931.63783     29.48 2022-04-28 07:30:00
# 1  2078.410             22.0  1931.62999     29.48 2022-04-28 07:30:00
# 2  2075.470             22.0  1985.40452     29.42 2022-05-09 07:30:00
# 3  2076.780             22.0  1955.71939     29.42 2022-05-09 07:30:00
# 4  2138.395             22.0  1978.53868     30.62 2022-05-22 07:30:00

# %%
# For each index in dataframe df...
for ind in df.index:
    # if TA or DIC at that index is Nan/empty...
    if math.isnan(df['TA (uM)'][ind]) or math.isnan(df['DIC (uM)'][ind]):
        # Drop that index
        df = df.drop(ind)

# %% [markdown]
# convert to UTC

# %%
daylight_start_date23=pd.Timestamp(datetime(2023,3,12,0,0,0))
daylight_end_date23 = pd.Timestamp(datetime(2023,11,5,0,0,0))
daylight_start_date22 = pd.Timestamp(datetime(2022,3,13,0,0,0))
daylight_end_date22 = pd.Timestamp(datetime(2022,11,6,0,0,0))

# %%
for ind in df.index: 
    if (df['DateTime'][ind] >= daylight_start_date23) & (df['DateTime'][ind] < daylight_end_date23):
        df['DateTime'][ind]=df['DateTime'][ind]+ timedelta(hours=4)
        
    elif (df['DateTime'][ind] >=daylight_start_date22) & (df['DateTime'][ind] < daylight_end_date22):
        df['DateTime'][ind] = df['DateTime'][ind] +timedelta(hours = 4) 
        
    else:
        df['DateTime'][ind] = df['DateTime'][ind] + timedelta(hours =5)

# %% [markdown]
# unit conversion

# %%
df['P']=0 #pressure

#density
df['rho_DIC'] =gsw.rho(df['Salinity'], df['DIC Temp (degC)'], df['P'])
df['rho_TA'] = gsw.rho(df['Salinity'], df['TA Temp (degC)'], df['P']) 

# converts DIC and TA 
df['DIC (umol/kg)'] = df['DIC (uM)'] / df['rho_DIC']/.001
df['TA (umol/kg)'] = df['TA (uM)'] / df['rho_TA']/.001

df.head()
# Out:
#                Sample          Time Location    depth  TA Temp (degC)  \
# 0       PLT 4/28/22 A  4/28/22 7:30      PLT  surface            20.9
# 1       PLT 4/28/22 B  4/28/22 7:30      PLT  surface            20.9
# 2   PLT 5/9/22 surf A   5/9/22 7:30      PLT  surface            20.3
# 3   PLT 5/9/22 surf B   5/9/22 7:30      PLT  surface            20.3
# 4  PLT 5/22/22 bottom  5/22/22 7:30      PLT   bottom            20.9
#
#     TA (uM)  DIC Temp (degC)    DIC (uM)  Salinity            DateTime  P  \
# 0  2078.825             22.0  1931.63783     29.48 2022-04-28 11:30:00  0
# 1  2078.410             22.0  1931.62999     29.48 2022-04-28 11:30:00  0
# 2  2075.470             22.0  1985.40452     29.42 2022-05-09 11:30:00  0
# 3  2076.780             22.0  1955.71939     29.42 2022-05-09 11:30:00  0
# 4  2138.395             22.0  1978.53868     30.62 2022-05-22 11:30:00  0
#
#        rho_DIC       rho_TA  DIC (umol/kg)  TA (umol/kg)
# ...

# %%
results = pyco2.sys(par1=df['TA (umol/kg)'],par2=df['DIC (umol/kg)'],par1_type=1,par2_type=2,salinity = df['Salinity'], temperature = df['DIC Temp (degC)'])
df['pH'] = results['pH']
df.head()
# Out:
#                Sample          Time Location    depth  TA Temp (degC)  \
# 0       PLT 4/28/22 A  4/28/22 7:30      PLT  surface            20.9
# 1       PLT 4/28/22 B  4/28/22 7:30      PLT  surface            20.9
# 2   PLT 5/9/22 surf A   5/9/22 7:30      PLT  surface            20.3
# 3   PLT 5/9/22 surf B   5/9/22 7:30      PLT  surface            20.3
# 4  PLT 5/22/22 bottom  5/22/22 7:30      PLT   bottom            20.9
#
#     TA (uM)  DIC Temp (degC)    DIC (uM)  Salinity            DateTime  P  \
# 0  2078.825             22.0  1931.63783     29.48 2022-04-28 11:30:00  0
# 1  2078.410             22.0  1931.62999     29.48 2022-04-28 11:30:00  0
# 2  2075.470             22.0  1985.40452     29.42 2022-05-09 11:30:00  0
# 3  2076.780             22.0  1955.71939     29.42 2022-05-09 11:30:00  0
# 4  2138.395             22.0  1978.53868     30.62 2022-05-22 11:30:00  0
#
#        rho_DIC       rho_TA  DIC (umol/kg)  TA (umol/kg)        pH
# ...

# %%
df.dropna()
# Out:
#                 Sample               Time Location    depth  TA Temp (degC)  \
# 0        PLT 4/28/22 A       4/28/22 7:30      PLT  surface            20.9
# 1        PLT 4/28/22 B       4/28/22 7:30      PLT  surface            20.9
# 2    PLT 5/9/22 surf A        5/9/22 7:30      PLT  surface            20.3
# 3    PLT 5/9/22 surf B        5/9/22 7:30      PLT  surface            20.3
# 4   PLT 5/22/22 bottom       5/22/22 7:30      PLT   bottom            20.9
# 5     PLT 5/22/22 surf       5/22/22 7:30      PLT  surface            20.6
# 8          PLT 6/13/22       6/13/22 7:30      PLT  surface            21.3
# 10         PLT 6/28/22       6/28/22 7:30      PLT  surface            21.3
# 11          PLT 7/5/22        7/5/22 7:30      PLT  surface            21.2
# 12         PLT 7/11/22       7/11/22 7:30      PLT  surface            21.2
# 13         PLT 7/19/22       7/19/22 7:30      PLT  surface            21.2
# ...

# %%
df620 = PLT.get_hydrocat('2021-11-01', '2023-05-05', 'PLT')
df720 = PLT.get_hydrocat('2021-11-01', '2023-05-05', 'GB')

# %%
df['sensor620 ph'] = np.zeros(len(df['DateTime']))
df['sensor720 ph'] = np.zeros(len(df['DateTime']))
for ind in df.index:
    p = df620.where(df620['DateTime'] > df.loc[ind]['DateTime'] - timedelta(hours = 0.1)).where(df620['DateTime'] < df.loc[ind]['DateTime'] + timedelta(hours = 0.1)).dropna()
    if p.size > 0:
        df['sensor620 ph'][ind] = p['pH total'].values.tolist()[0]
    else:
        df['sensor620 ph'][ind] = np.nan
    q = df720.where(df720['DateTime'] > df.loc[ind]['DateTime'] - timedelta(hours = 0.1)).where(df720['DateTime'] < df.loc[ind]['DateTime'] + timedelta(hours = 0.1)).dropna()
    
    if q.size > 0:
        df['sensor720 ph'][ind] = q['pH total'].values.tolist()[0]
    else:
        df['sensor720 ph'][ind] = np.nan

# %%
df720
# Out:
#                         TmStamp        hydrocatStart  hydrocatTemperature  \
# 0      2021-11-01T00:11:15.000Z                 None              14.8890
# 1      2021-11-01T00:26:15.000Z                 None              15.0194
# 2      2021-11-01T00:41:15.000Z                 None              14.6682
# 3      2021-11-01T00:56:15.000Z                 None              14.6739
# 4      2021-11-01T01:11:15.000Z                 None              14.6536
# ...                         ...                  ...                  ...
# 48140  2023-05-04T22:46:31.000Z  05/04/2023 22:45:00              12.6642
# 48141  2023-05-04T23:01:30.600Z  05/04/2023 23:00:00              12.7450
# 48142  2023-05-04T23:16:30.600Z  05/04/2023 23:15:00              12.6469
# 48143  2023-05-04T23:31:30.600Z  05/04/2023 23:30:00              12.6514
# 48144  2023-05-04T23:46:31.000Z  05/04/2023 23:45:00              12.7073
#
#        hydrocatConductivity  hydrocatDissOxygen  hydrocatSalinity  \
# ...

# %% [markdown]
# # NOTE
# I changed this cell so it would read my document. Remember to change this back!

# %%
# pH_data = pd.read_csv('/Users/georg/Downloads/pH.csv') 
pH_data = pd.read_csv('/Users/akbaskind/Desktop/Dissertation/pH.csv')
pH_data.drop(pH_data.tail(6).index, inplace = True)

# %%
labGB = df.where(df['Location']== 'GB').dropna()
labPLT = df.where(df['Location']== 'PLT').dropna()
labGB
# Out:
#            Sample            Time Location    depth  TA Temp (degC)   TA (uM)  \
# 21    GB B 9/9/22    9/9/22 11:30       GB  surface            21.3  1957.870
# 22    GB A 9/9/22    9/9/22 11:30       GB  surface            21.3  1955.840
# 25   GB B 9/20/22   9/20/22 11:30       GB  surface            21.3  2051.600
# 26   GB A 9/20/22   9/20/22 11:30       GB  surface            21.3  2051.930
# 28  GB A 10/25/22  10/25/22 11:30       GB  surface            21.3  2047.245
# 29  GB B 10/25/22  10/25/22 11:30       GB  surface            21.3  2043.310
# 32   GB A 11/9/22   11/9/22 11:30       GB  surface            21.3  2079.940
# 33   GB B 11/9/22   11/9/22 11:30       GB  surface            21.3  2080.755
# 46          GB169    2/1/23 11:30       GB                     20.8  1651.600
# 57          GB196   3/22/23 10:15       GB  surface            21.3  2025.780
#
#     DIC Temp (degC)  DIC (uM)  Salinity            DateTime    P      rho_DIC  \
# ...

# %%
pH_data["DateTime"] = pd.to_datetime(pH_data["DateTime (UTC-04:00)"]) - timedelta(hours = 5)
pH_data.head()
# Out:
#      FrameSync DateTime (UTC-04:00)  Sample Number (#)  Error Flags (#)  \
# 0  SSPHOX02346         9/9/22 21:00                  1                0
# 1  SSPHOX02346         9/9/22 21:15                  2                0
# 2  SSPHOX02346         9/9/22 21:30                  3                0
# 3  SSPHOX02346         9/9/22 21:45                  4                0
# 4  SSPHOX02346         9/9/22 22:00                  5                0
#
#    Temperature (Celsius)  External pH (pH)  Internal pH (pH)  \
# 0                23.0835            7.7486            7.7211
# 1                22.9676            7.7456            7.7146
# 2                23.0644            7.7556            7.7256
# 3                23.1619            7.7569            7.7270
# 4                23.0252            7.7719            7.7369
#
#    External pH (Volt)  Internal pH (Volt)  pH Temperature (Celsius)  \
# 0           -0.909148           -0.962519                   22.9960
# ...

# %% [markdown]
# SeaFET outlier removal using STDEV

# %% [markdown]
# # ANOTHER NOTE
#
# You plotted the same thing twice but labeled them different things.
#
# ```python
# ax.plot(pH_data['DateTime'].to_numpy(), pH_data['External pH (pH)'].to_numpy(), color = 'blue', label = 'seaFET sensor')
# ax.plot(pH_data['DateTime'].to_numpy(), pH_data['External pH (pH)'].to_numpy(), color = 'red', label = 'QP NO OUTLIERS')
# ```
#
# Presumably, you want to plot the SeaFET data with outliers removed. In the line `seaFET_STD = rmoutliers_STD3(pH_data, 'External pH (pH)')` you did indeed remove the outliers, but you called this outlier-less dataframe `seaFET_STD`. To change this, you'll want to change one of your lines where you plot. For example instead of
#
# ```python
# ax.plot(pH_data['DateTime'].to_numpy(), pH_data['External pH (pH)'].to_numpy(), color = 'blue', label = 'seaFET sensor')
# ax.plot(pH_data['DateTime'].to_numpy(), pH_data['External pH (pH)'].to_numpy(), color = 'red', label = 'QP NO OUTLIERS')
# ```
#
# You might try
#
# ```python
# ax.plot(pH_data['DateTime'].to_numpy(), pH_data['External pH (pH)'].to_numpy(), color = 'blue', label = 'seaFET sensor')
# ax.plot(seaFET_STD['DateTime'].to_numpy(), seaFET_STD['External pH (pH)'].to_numpy(), color = 'red', label = 'seaFET NO OUTLIERS')
# ```

# %%
def rmoutliers_STD3(dataframe, var): 
    stdev= dataframe[var].std()
    mean = dataframe[var].mean()
    lower=mean-2*stdev
    upper= mean+2*stdev
    
    for ind in dataframe.index: 
        if dataframe[var][ind]> upper: 
            dataframe=dataframe.drop(ind) 
        elif dataframe[var][ind] <lower: 
            dataframe = dataframe.drop(ind) 
    dv=dataframe.reset_index(drop=True)
    return dv

seaFET_STD = rmoutliers_STD3(pH_data, 'External pH (pH)')

fig,ax = plt.subplots(figsize=[10,10])
ax.plot(pH_data['DateTime'].to_numpy(), pH_data['External pH (pH)'].to_numpy(), color = 'blue', label = 'seaFET sensor')
ax.plot(pH_data['DateTime'].to_numpy(), pH_data['External pH (pH)'].to_numpy(), color = 'red', label = 'QP NO OUTLIERS')
ax.xaxis.set_major_locator(mdates.MonthLocator(interval=1))
ax.tick_params('x',labelsize = 12, labelrotation = 90)
ax.tick_params('y',labelsize = 12)
ax.legend(fontsize = 12)
ax.set_xlabel('Year-Month', fontsize = 12)
# Out:
# Text(0.5, 0, 'Year-Month')

# %% [markdown]
# ## implementing that change would look like this
#  Note that this way of removing outliers doesn't affect this dataset all that much. This is because the SeaFET sensor is very precise (the error is 0.05, as opposed to 0.1), and it was calibrated just before this deployment.

# %%
fig,ax = plt.subplots(figsize=[10,10])
ax.plot(pH_data['DateTime'].to_numpy(), pH_data['External pH (pH)'].to_numpy(), color = 'blue', label = 'seaFET sensor')
ax.plot(seaFET_STD['DateTime'].to_numpy(), seaFET_STD['External pH (pH)'].to_numpy(), color = 'red', label = 'SeaFET NO OUTLIERS')
ax.xaxis.set_major_locator(mdates.MonthLocator(interval=1))
ax.tick_params('x',labelsize = 12, labelrotation = 90)
ax.tick_params('y',labelsize = 12)
ax.legend(fontsize = 12)
ax.set_xlabel('Year-Month', fontsize = 12)
# Out:
# Text(0.5, 0, 'Year-Month')

# %% [markdown]
# # Note on Markdown cells
# You can create headers in the markdown cell by beginning with '#'. Subheaders use '##', '###', etc.
#
# If you want to quote a line of code inline you begin the code with the symbol `

# %% [markdown]
# If you want to quote a whole block of code insert 3 of `

# %% [markdown]
# Paste your code and conclude with 3 more `

# %% [markdown]
# It will look something like this
#
# ```
# spreadsheet_key_ = '1XXFdxrZDcHTYUnLbQEZSgqvJpeNLIsKkE_HYJu1yTIo'
# wks_name_ = 'MV'
# ```

# %% [markdown]
# # MV sensor Data

# %%
spreadsheet_key_ = '1XXFdxrZDcHTYUnLbQEZSgqvJpeNLIsKkE_HYJu1yTIo'
wks_name_ = 'MV'

#Opening the worksheet by using Worksheet ID
workbook = gc.open_by_key(spreadsheet_key_)
#Selecting which sheet to pulling the data
sheet = workbook.worksheet(wks_name_)

#Pulling the data and transform it to the data frame
values = sheet.get_all_values()
MV = pd.DataFrame(values[1:], columns = values[0])
MV = MV.iloc[:, 0:12]
MV.head()
# Out:
#    Site Agency      Date   Time            C Temp SpC Salinity DO% DO Conc  \
# 0  B6-S   gsovs  05/01/22  0:00  5/1/22 0:00
# 1  B6-S   gsovs  05/01/22  0:15  5/1/22 0:15
# 2  B6-S   gsovs  05/01/22  0:30  5/1/22 0:30
# 3  B6-S   gsovs  05/01/22  0:45  5/1/22 0:45
# 4  B6-S   gsovs  05/01/22  1:00  5/1/22 1:00
#
#   Depth pH
# 0
# 1
# 2
# 3
# 4

# %%
# surfaceMV = MV.iloc[:,0:15]
# surfaceMV = surfaceMV.drop(columns = ['Site', "Agency ", 'surface FS'])
# surfaceMV=surfaceMV.rename(columns ={"C":"DateTime", 'Date':'Date'})

# %%
MV['pH'] = pd.to_numeric(MV['pH'])
# lab['TA Temp (degC)'] = pd.to_numeric(lab['TA Temp (degC)'])
# lab['DIC (uM)'] = pd.to_numeric(lab['DIC (uM)'])
MV['Temp'] = pd.to_numeric(MV['Temp'])
MV['Salinity'] = pd.to_numeric(MV['Salinity'])
MV['DateTime'] = pd.to_datetime(MV['C'])

# %%
for ind in MV.index:
    if math.isnan(MV['pH'][ind]):
        MV = MV.drop(ind)
MV
# Out:
#        Site Agency      Date    Time               C    Temp      SpC  \
# 2353   B6-S   gsovs  05/25/22  12:15   5/25/22 12:15  18.498  45164.1
# 2354   B6-S   gsovs  05/25/22  12:30   5/25/22 12:30  18.452  45257.7
# 2355   B6-S   gsovs  05/25/22  12:45   5/25/22 12:45  18.399  45304.7
# 2356   B6-S   gsovs  05/25/22  13:00   5/25/22 13:00  18.376  45345.2
# 2357   B6-S   gsovs  05/25/22  13:15   5/25/22 13:15  18.230    45431
# ...     ...     ...       ...    ...             ...     ...      ...
# 19722  B6-S   gsovs  11/22/22  10:30  11/22/22 10:30   8.814  46579.1
# 19723  B6-S   gsovs  11/22/22  10:45  11/22/22 10:45   8.680  46538.9
# 19724  B6-S   gsovs  11/22/22  11:00  11/22/22 11:00   8.646  46527.2
# 19725  B6-S   gsovs  11/22/22  11:15  11/22/22 11:15   8.582    46492
# 19726  B6-S   gsovs  11/22/22  11:30  11/22/22 11:30   8.586  46472.2
#
#        Salinity    DO% DO Conc  Depth    pH            DateTime
# ...

# %% [markdown]
# # Reset index
# Notice when you drop `nan` the row numbers/indexes don't start from 0. It is often helpful to renumbered the rows using `reset_index(drop = True)`.
#
# It will look as follows:
# ```python
# df = df.reset_index(drop=True)
# ```

# %% [markdown]
# NBFSM pH

# %%
resultsMV = pyco2.sys(par1=MV['pH'], par1_type=3, temperature = MV['Temp'], salinity = MV['Salinity'],opt_pH_scale = 4)
MV['pH total'] = resultsMV['pH_total']
MV
# Out:
#        Site Agency      Date    Time               C    Temp      SpC  \
# 2353   B6-S   gsovs  05/25/22  12:15   5/25/22 12:15  18.498  45164.1
# 2354   B6-S   gsovs  05/25/22  12:30   5/25/22 12:30  18.452  45257.7
# 2355   B6-S   gsovs  05/25/22  12:45   5/25/22 12:45  18.399  45304.7
# 2356   B6-S   gsovs  05/25/22  13:00   5/25/22 13:00  18.376  45345.2
# 2357   B6-S   gsovs  05/25/22  13:15   5/25/22 13:15  18.230    45431
# ...     ...     ...       ...    ...             ...     ...      ...
# 19722  B6-S   gsovs  11/22/22  10:30  11/22/22 10:30   8.814  46579.1
# 19723  B6-S   gsovs  11/22/22  10:45  11/22/22 10:45   8.680  46538.9
# 19724  B6-S   gsovs  11/22/22  11:00  11/22/22 11:00   8.646  46527.2
# 19725  B6-S   gsovs  11/22/22  11:15  11/22/22 11:15   8.582    46492
# 19726  B6-S   gsovs  11/22/22  11:30  11/22/22 11:30   8.586  46472.2
#
#        Salinity    DO% DO Conc  Depth    pH            DateTime  pH total
# ...

# %%
fig,ax=plt.subplots(figsize=[10,10])
ax.scatter (MV['DateTime'], MV['pH total'])

# %% [markdown]
# MV removal of outilers

# %% [markdown]
# # STD function
# You previously defined with `rmoutliers_STD3` above:
# ```python
# def rmoutliers_STD3(dataframe, var):
#     stdev= dataframe[var].std()
#     mean = dataframe[var].mean()
#     lower=mean-2*stdev
#     upper= mean+2*stdev
#
#     for ind in dataframe.index:
#         if dataframe[var][ind]> upper:
#             dataframe=dataframe.drop(ind)
#         elif dataframe[var][ind] <lower:
#             dataframe = dataframe.drop(ind)
#     dv=dataframe.reset_index(drop=True)
#     return dv
# ```
#
# You don't need to redefine the function every time you need it. You can just call it again. For example

# %%
MV_STD_abby = rmoutliers_STD3(MV, 'pH total')
MV_STD_abby.head()
# Out:
#    Site Agency      Date    Time              C    Temp      SpC  Salinity  \
# 0  B6-S   gsovs  05/25/22  12:15  5/25/22 12:15  18.498  45164.1     29.29
# 1  B6-S   gsovs  05/25/22  12:30  5/25/22 12:30  18.452  45257.7     29.36
# 2  B6-S   gsovs  05/25/22  12:45  5/25/22 12:45  18.399  45304.7     29.39
# 3  B6-S   gsovs  05/25/22  13:00  5/25/22 13:00  18.376  45345.2     29.42
# 4  B6-S   gsovs  05/25/22  13:15  5/25/22 13:15  18.230    45431     29.48
#
#      DO% DO Conc  Depth    pH            DateTime  pH total
# 0  108.3    8.52  1.043  7.91 2022-05-25 12:15:00  7.780182
# 1  106.9    8.42  1.045  7.90 2022-05-25 12:30:00  7.770350
# 2  108.1    8.52  1.056  7.91 2022-05-25 12:45:00  7.780484
# 3  107.8     8.5  1.051  7.92 2022-05-25 13:00:00  7.790562
# 4  107.5    8.49   1.04  7.91 2022-05-25 13:15:00  7.780906

# %%
def rmoutliers_STD1(dataframe, var): 
    stdev= dataframe[var].std()
    mean = dataframe[var].mean()
    lower=mean-2*stdev
    upper= mean+2*stdev
    
    for ind in dataframe.index: 
        if dataframe[var][ind]> upper: 
            dataframe=dataframe.drop(ind) 
        elif dataframe[var][ind] <lower: 
            dataframe = dataframe.drop(ind) 
    dv=dataframe.reset_index(drop=True)
    return dv

MV_STD = rmoutliers_STD1(MV, 'pH total')

# %% [markdown]
# ### maybe label your y axis?
# low key i get pretty sloppy about that but i do be out here trying to make you a better coder than i am

# %%
fig,ax = plt.subplots(figsize=[10,10])
ax.plot(MV['DateTime'].to_numpy(), MV['pH total'].to_numpy(), color = 'blue', label = 'MV sensor')
ax.plot(MV_STD['DateTime'].to_numpy(), MV_STD['pH total'].to_numpy(), color = 'red', label = 'MV NO OUTLIERS')
ax.xaxis.set_major_locator(mdates.MonthLocator(interval=1))
ax.tick_params('x',labelsize = 12, labelrotation = 90)
ax.tick_params('y',labelsize = 12)
ax.legend(fontsize = 12)
ax.set_xlabel('Year-Month', fontsize = 12)
# Out:
# Text(0.5, 0, 'Year-Month')

# %% [markdown]
# QP sensor Data

# %%
spreadsheet_key_QP = '1-hmDs8AkeL9l-_6lbPb6_SkD8AqoVF6OfmBqsm55PEU'
wks_name_QP = 'QP'

#Opening the worksheet by using Worksheet ID
workbook = gc.open_by_key(spreadsheet_key_QP)
#Selecting which sheet to pulling the data
sheet = workbook.worksheet(wks_name_QP)

#Pulling the data and transform it to the data frame
values = sheet.get_all_values()
QP = pd.DataFrame(values[1:], columns = values[0])
QP = QP.iloc[:, 0:12]
QP.head()
# Out:
#    Site Agency      Date   Time            C Temp SpC Salinity DO% DO Conc  \
# 0  B7-S   gsoqs  05/01/22  0:00  5/1/22 0:00
# 1  B7-S   gsoqs  05/01/22  0:15  5/1/22 0:15
# 2  B7-S   gsoqs  05/01/22  0:30  5/1/22 0:30
# 3  B7-S   gsoqs  05/01/22  0:45  5/1/22 0:45
# 4  B7-S   gsoqs  05/01/22  1:00  5/1/22 1:00
#
#   Depth pH
# 0
# 1
# 2
# 3
# 4

# %%
QP['pH'] = pd.to_numeric(QP['pH'])
# lab['TA Temp (degC)'] = pd.to_numeric(lab['TA Temp (degC)'])
# lab['DIC (uM)'] = pd.to_numeric(lab['DIC (uM)'])
QP['Temp'] = pd.to_numeric(QP['Temp'])
QP['Salinity'] = pd.to_numeric(QP['Salinity'])
QP["DateTime"] = pd.to_datetime(QP["C"])

# %%
for ind in QP.index:
    if math.isnan(QP['pH'][ind]):
        QP = QP.drop(ind)
QP
# Out:
#        Site Agency      Date    Time               C   Temp    SpC  Salinity  \
# 2336   B7-S   gsoqs  05/25/22   8:00    5/25/22 8:00  16.35  47.14     30.70
# 2337   B7-S   gsoqs  05/25/22   8:15    5/25/22 8:15  16.44  47.14     30.71
# 2338   B7-S   gsoqs  05/25/22   8:30    5/25/22 8:30  16.35  47.18     30.73
# 2339   B7-S   gsoqs  05/25/22   8:45    5/25/22 8:45  16.58  47.09     30.67
# 2340   B7-S   gsoqs  05/25/22   9:00    5/25/22 9:00  16.56  47.12     30.69
# ...     ...     ...       ...    ...             ...    ...    ...       ...
# 19718  B7-S   gsoqs  11/22/22   9:30   11/22/22 9:30   9.66  44.97     28.91
# 19719  B7-S   gsoqs  11/22/22   9:45   11/22/22 9:45   9.64  45.02     28.95
# 19720  B7-S   gsoqs  11/22/22  10:00  11/22/22 10:00   9.66  44.33     28.46
# 19721  B7-S   gsoqs  11/22/22  10:15  11/22/22 10:15   9.67  44.15     28.33
# 19722  B7-S   gsoqs  11/22/22  10:30  11/22/22 10:30   9.69  44.38     28.49
#
# ...

# %% [markdown]
# QP pH calc

# %%
resultsMV = pyco2.sys(par1=QP['pH'], par1_type=3, temperature = QP['Temp'], salinity = QP['Salinity'],opt_pH_scale = 4)
QP['pH total'] = resultsMV['pH_total']
QP
# Out:
#        Site Agency      Date    Time               C   Temp    SpC  Salinity  \
# 2336   B7-S   gsoqs  05/25/22   8:00    5/25/22 8:00  16.35  47.14     30.70
# 2337   B7-S   gsoqs  05/25/22   8:15    5/25/22 8:15  16.44  47.14     30.71
# 2338   B7-S   gsoqs  05/25/22   8:30    5/25/22 8:30  16.35  47.18     30.73
# 2339   B7-S   gsoqs  05/25/22   8:45    5/25/22 8:45  16.58  47.09     30.67
# 2340   B7-S   gsoqs  05/25/22   9:00    5/25/22 9:00  16.56  47.12     30.69
# ...     ...     ...       ...    ...             ...    ...    ...       ...
# 19718  B7-S   gsoqs  11/22/22   9:30   11/22/22 9:30   9.66  44.97     28.91
# 19719  B7-S   gsoqs  11/22/22   9:45   11/22/22 9:45   9.64  45.02     28.95
# 19720  B7-S   gsoqs  11/22/22  10:00  11/22/22 10:00   9.66  44.33     28.46
# 19721  B7-S   gsoqs  11/22/22  10:15  11/22/22 10:15   9.67  44.15     28.33
# 19722  B7-S   gsoqs  11/22/22  10:30  11/22/22 10:30   9.69  44.38     28.49
#
# ...

# %%
fig,ax=plt.subplots(figsize=[10,10])
ax.plot(pH_data['DateTime'].to_numpy(),pH_data['External pH (pH)'].to_numpy(), color = 'c',label = 'SeaFET')
ax.xaxis.set_major_locator(mdates.MonthLocator(interval=1))
ax.tick_params('x',labelsize = 12, labelrotation = 90)
ax.tick_params('y',labelsize = 12)
ax.legend(fontsize = 12)
ax.set_xlabel('Year-Month')
ax.set_ylabel('pH')
# Out:
# Text(0, 0.5, 'pH')

# %% [markdown]
# ## Again you don't need to redefine your `rmoutliers_STD` function

# %%
def rmoutliers_STD2(dataframe, var): 
    stdev= dataframe[var].std()
    mean = dataframe[var].mean()
    lower=mean-2*stdev
    upper= mean+2*stdev
    
    for ind in dataframe.index: 
        if dataframe[var][ind]> upper: 
            dataframe=dataframe.drop(ind) 
        elif dataframe[var][ind] <lower: 
            dataframe = dataframe.drop(ind) 
    dv=dataframe.reset_index(drop=True)
    return dv

QP_STD = rmoutliers_STD2(QP, 'pH total')

fig,ax = plt.subplots(figsize=[10,10])
ax.plot(QP['DateTime'].to_numpy(), QP['pH total'].to_numpy(), color = 'blue', label = 'QP sensor')
ax.plot(QP_STD['DateTime'].to_numpy(), QP_STD['pH total'].to_numpy(), color = 'red', label = 'QP NO OUTLIERS')
ax.xaxis.set_major_locator(mdates.MonthLocator(interval=1))
ax.tick_params('x',labelsize = 12, labelrotation = 90)
ax.tick_params('y',labelsize = 12)
ax.legend(fontsize = 12)
ax.set_xlabel('Year-Month', fontsize = 12)
# Out:
# Text(0.5, 0, 'Year-Month')

# %% [markdown]
# Pulling Andy Davis data using PLT.py

# %%
# %cd directory
# %run PLT.py
# Out:
# [WinError 2] The system cannot find the file specified: 'directory'
# C:\Users\georg\OneDrive\Documents\Python Scripts

# %%
AD = PLT.get_hydrocat('2022-01-01', '2023-05-01', 'PLT')

# %%
AndyPLT = AD[['TmStamp', 'hydrocatStart', 'hydrocatTemperature', 'hydrocatConductivity', 'hydrocatDissOxygen', 'hydrocatSalinity', 'hydrocatFluorescence','hydrocatTurbidity','hydrocatPH','DateTime','pH total']]
AndyPLT['Temp (C)'] = pd.to_numeric(AndyPLT['hydrocatTemperature'])
AndyPLT['DissOxygen'] = pd.to_numeric(AndyPLT['hydrocatDissOxygen'])
AndyPLT['Time'] = pd.to_datetime(AndyPLT['DateTime'])
AndyPLT['pH'] = pd.to_numeric(AndyPLT['pH total'])
AndyPLT.head()
# Out:
#                     TmStamp hydrocatStart  hydrocatTemperature  \
# 0  2022-01-04T09:31:15.400Z          None               6.5078
# 1  2022-01-04T10:46:15.400Z          None               6.3631
# 2  2022-01-04T11:01:15.200Z          None               6.3063
# 3  2022-01-04T11:16:15.200Z          None               6.2367
# 4  2022-01-04T11:31:15.200Z          None               6.2593
#
#    hydrocatConductivity  hydrocatDissOxygen  hydrocatSalinity  \
# 0               31.0263               9.592           30.7871
# 1               30.9445               9.663           30.8278
# 2               30.8235               9.633           30.7459
# 3               30.7264               9.680           30.7015
# 4               30.6975               9.698           30.6492
#
#    hydrocatFluorescence  hydrocatTurbidity  hydrocatPH  \
# 0                 7.478             30.272        8.04
# 1                 1.844              3.473        8.04
# ...

# %%
start_date = '2022-01-01'
end_date ='2023-05-01'
# buoy= 'Jamestown/620/PLT'
ADGB=PLT.get_hydrocat(start_date, end_date, 'GB')

# %%
AndyGB = ADGB[['TmStamp', 'hydrocatStart', 'hydrocatTemperature', 'hydrocatConductivity', 'hydrocatDissOxygen', 'hydrocatSalinity', 'hydrocatFluorescence','hydrocatTurbidity','hydrocatPH','DateTime','pH total']]
AndyGB['Temp (C)'] = pd.to_numeric(AndyGB['hydrocatTemperature'])
AndyGB['DissOxygen'] = pd.to_numeric(AndyGB['hydrocatDissOxygen'])
AndyGB['Time'] = pd.to_datetime(AndyGB['DateTime'])
AndyGB['pH'] = pd.to_numeric(AndyGB['pH total'])
AndyGB.head()
# Out:
#                     TmStamp hydrocatStart  hydrocatTemperature  \
# 0  2022-01-02T05:46:15.400Z          None               7.3282
# 1  2022-01-03T00:16:15.600Z          None               7.1784
# 2  2022-01-03T00:31:15.400Z          None               7.0309
# 3  2022-01-03T01:16:15.400Z          None               7.0331
# 4  2022-01-03T02:01:15.400Z          None               7.0196
#
#    hydrocatConductivity  hydrocatDissOxygen  hydrocatSalinity  \
# 0               30.8639               9.294           29.8873
# 1               30.4087               9.521           29.5282
# 2               29.9612               9.687           29.1730
# 3               30.0389               9.922           29.2548
# 4               30.1117               9.844           29.3446
#
#    hydrocatFluorescence  hydrocatTurbidity  hydrocatPH  \
# 0                21.481             74.668        8.15
# 1                21.745             77.935        8.17
# ...

# %% [markdown]
# # So it seems like below you are copying over what I put in my function `PLT.get_hydrocat()`.
#
# Since you executed `%run PLT.py` that basically loads the function for you so you don't need to copy over all the info within the function.

# %%
matched_start = re.match("\d{4}-\d{2}-\d{2}", start_date)
matched_end = re.match("\d{4}-/d{2}-\d{2}", end_date)

# %%
if bool(not matched_start) or bool (not matched_end): 
    print('Error: Input date must be a string of the form YYYY-MM-DD')
# Out:
# Error: Input date must be a string of the form YYYY-MM-DD

# %%
a = time.strptime(start_date, '%Y-%m-%d')
b = time.strptime(end_date, '%Y-%m-%d')
if a>b: 
    start=start_date
    start_date = end_date
    end_date=start

# %%
if buoy == 'Jamestown' or buoy == '620' or buoy == 'PLT': 
    URL = 'https://api.riddc.brown.edu/telemetry/Buoy-620/CoreMetrics/range?start=' + start_date + '&end=' + end_date
elif buoy == 'Greenwich Bay' or buoy == '720' or buoy == 'GB':
    URL = 'https://api.riddc.brown.edu/telemetry/Buoy-720/CoreMetrics/range?start=' + start_date + '&end=' + end_date
else: 
    print('Buoy options are 620 for Jamestown/PLT or 720 for Greenwich Bay/GB.')
# Out:
# Buoy options are 620 for Jamestown/PLT or 720 for Greenwich Bay/GB.

# %%
# r = requests.get(URL) 
# JSON = AD.json()
# dj=pd.DataFrame(JSON['Hydrocat']) 


for ind in df620.index: 
    if df620['hydrocatPH'][ind]<=0: 
        df620=df620.drop(ind)
        
    elif math.isnan(df620['hydrocatPH'][ind]):
        df620 = df620.drop(ind)
    elif math.isnan(df620['hydrocatDissOxygen'][ind]):
        df620 = df620.drop(ind)
    elif math.isnan(df620['hydrocatSalinity'][ind]):
        df620 = df620.drop(ind)
    elif math.isnan(df620['hydrocatTemperature'][ind]):
        df620 = df620.drop(ind)
AD620 = df620.reset_index(drop=True)

# %%
AD620['DateTime'] = np.zeros(len(AD620['TmStamp']))
for ind in AD620.index: 
    AD620['DateTime'][ind] = datetime.strptime(AD620['TmStamp'][ind], '%Y-%m-%dT%H:%M:%S.%fZ')
results = pyco2.sys(par1=AD620['hydrocatPH'], par1_type=3,temperature = AD620['hydrocatTemperature'], salinity = AD620['hydrocatSalinity'],opt_pH_scale = 4)
AD620['pH'] = results['pH_total']
AD620
# Out:
#                         TmStamp        hydrocatStart  hydrocatTemperature  \
# 0      2021-11-15T12:11:25.400Z                 None              12.7368
# 1      2021-11-15T12:26:15.000Z                 None              12.6987
# 2      2021-11-15T12:41:15.000Z                 None              12.6967
# 3      2021-11-15T12:56:15.000Z                 None              12.6971
# 4      2021-11-15T13:11:15.000Z                 None              12.6923
# ...                         ...                  ...                  ...
# 37577  2023-05-04T22:46:29.000Z  05/04/2023 22:45:00              12.5201
# 37578  2023-05-04T23:01:29.000Z  05/04/2023 23:00:00              12.5638
# 37579  2023-05-04T23:16:29.000Z  05/04/2023 23:15:00              12.5690
# 37580  2023-05-04T23:31:29.000Z  05/04/2023 23:30:00              12.5633
# 37581  2023-05-04T23:46:29.000Z  05/04/2023 23:45:00              12.5434
#
#        hydrocatConductivity  hydrocatDissOxygen  hydrocatSalinity  \
# ...

# %% [markdown]
# Perhaps you went through every step of the function to understand what is actually happened. Totally valid, but just want to be sure you don't feel you HAVE to individually run every step of the function manually.

# %%
fig,ax=plt.subplots(figsize=[10,10])
ax.plot(AndyPLT['Time'].to_numpy(), AndyPLT['pH'].to_numpy(), color = 'm', label = 'Hydrocat')

# %% [markdown]
# # Fun aside about plot colors
#
# If you want more color options for plotting, you can use HEX color codes. Often I just google HEX color picker and there are tons of websites that give you *countless* colors and their corresponding hex codes.
#
# So let's say you want your plot to be lavender. Instead of using `color = 'black'` (or whatever other color) you can use the hex code for lavender #E6E6FA: `color = '#E6E6FA'`.

# %%
fig,ax=plt.subplots(figsize=[30,15])
ax.scatter(labPLT['DateTime'], labPLT['pH'], color = 'hotpink', marker = 'H',edgecolors='black',s= 90, label = 'Lab PLT', zorder = 5)
ax.plot(QP['DateTime'].to_numpy(),QP['pH'].to_numpy(), color = 'black',label = 'NBFSM - QP', zorder=3)
ax.plot(pH_data['DateTime'].to_numpy(),pH_data['External pH (pH)'].to_numpy(), color = 'maroon',label = 'SeaFET', zorder=4)
# ax.plot(AndyPLT['Time'].to_numpy(), AndyPLT['pH'].to_numpy(), color = 'c', label = 'Hydrocat PLT',zorder = 1)
ax.plot(df620['DateTime'].to_numpy(),df620['pH total'].to_numpy(),color ='purple', label = 'sensor 620',zorder=2)
ax.xaxis.set_major_locator(mdates.MonthLocator(interval=1))
ax.tick_params('x',labelsize = 12, labelrotation = 90)
ax.tick_params('y',labelsize = 12)
ax.legend(fontsize = 12)
ax.set_xlabel('Year-Month')
ax.set_ylabel('pH')
# Out:
# Text(0, 0.5, 'pH')

# %% [markdown]
# Graph comparing Dissolved Oxygen and pH using Andy Davis' PLT Data

# %% [markdown]
# You loaded Andy's buoys several times throughout this script as AndyGB/AndyPLT, df620/df720, AD620/AD720, etc. To streamline your code, I would recommend loading the dataset only once and using that same dataframe consistently.
#
# Then if you want to drop outliers or something you can just overwrite the same dataset. For example
# ```
# AndyGB = AndyGB.rmoutliers_STD(args)
# ```

# %%
fig,ax=plt.subplots(figsize=[30,15])
ax.scatter(labGB['DateTime'],labGB['pH'], color = 'lightgreen', marker = 'D',edgecolors='black', s =80, label = 'Lab GB', zorder = 5)
# ax.scatter(labPLT['DateTime'], labPLT['pH'], color = 'mediumseagreen', marker = 'H',edgecolors='black',s= 80, label = 'Lab PLT', zorder = 5)
# ax.plot(pH_data['DateTime'].to_numpy(),pH_data['External pH (pH)'].to_numpy(), color = 'maroon',label = 'SeaFET', zorder=4)
ax.plot(MV['DateTime'].to_numpy(),MV['pH'].to_numpy(), color = 'crimson',label = 'NBFSM - MV', zorder=3)
# ax.plot(QP['DateTime'].to_numpy(),QP['pH'].to_numpy(), color = 'black',label = 'NBFSM - QP', zorder=3)
# ax.plot(AndyPLT['Time'].to_numpy(), AndyPLT['pH'].to_numpy(), color = 'orange', label = 'Hydrocat PLT',zorder = 1)
# ax.plot(AndyGB['Time'].to_numpy(), AndyGB['pH'].to_numpy(), color = 'lightcoral', label = 'Hydrocat GB', zorder=0)
ax.plot(df720['DateTime'].to_numpy(),df720['pH total'].to_numpy(),color ='orange', label = 'sensor 720',zorder=2)
ax.xaxis.set_major_locator(mdates.MonthLocator(interval=1))
ax.tick_params('x',labelsize = 12, labelrotation = 90)
ax.tick_params('y',labelsize = 12)
ax.legend(fontsize = 12)
ax.set_xlabel('Year-Month')
ax.set_ylabel('pH')
# Out:
# Text(0, 0.5, 'pH')

# %%
AD620
# Out:
#                         TmStamp        hydrocatStart  hydrocatTemperature  \
# 0      2021-11-15T12:11:25.400Z                 None              12.7368
# 1      2021-11-15T12:26:15.000Z                 None              12.6987
# 2      2021-11-15T12:41:15.000Z                 None              12.6967
# 3      2021-11-15T12:56:15.000Z                 None              12.6971
# 4      2021-11-15T13:11:15.000Z                 None              12.6923
# ...                         ...                  ...                  ...
# 37577  2023-05-04T22:46:29.000Z  05/04/2023 22:45:00              12.5201
# 37578  2023-05-04T23:01:29.000Z  05/04/2023 23:00:00              12.5638
# 37579  2023-05-04T23:16:29.000Z  05/04/2023 23:15:00              12.5690
# 37580  2023-05-04T23:31:29.000Z  05/04/2023 23:30:00              12.5633
# 37581  2023-05-04T23:46:29.000Z  05/04/2023 23:45:00              12.5434
#
#        hydrocatConductivity  hydrocatDissOxygen  hydrocatSalinity  \
# ...

# %%
fig,ax = plt.subplots (figsize = [15,15]) 
plt.scatter(AD620['DateTime'], AD620['pH'])

# %%
fig,ax = plt.subplots (figsize = [15,15]) 
ax.scatter(AD620['hydrocatDissOxygen'],AD620['pH'], color = 'mediumseagreen',label='hydrocat 620 PLT w/ correction',zorder=1)
x = AD620['hydrocatDissOxygen'].to_numpy().reshape(-1,1)
y= AD620['pH'].to_numpy().reshape(-1,1)
model = LinearRegression().fit(x, y)

y_pred=model.predict(x)
delt = mean_absolute_error(y,y_pred) 
mockX = np.arange(AD620['hydrocatDissOxygen'].min(), AD620['hydrocatDissOxygen'].max(), 0.1).reshape(-1, 1)
mockY = model.predict(mockX)
ax.fill_between(mockX[:,0], mockY[:,0],mockY[:,0] + 2*delt, color = 'r', alpha = 0.2)
ax.fill_between(mockX[:,0], mockY[:,0],mockY[:,0] - 2*delt, color = 'r', alpha=0.2) 


# ax.scatter(AndyPLT['DissOxygen'],AndyPLT['pH'], color = 'purple',label='hydrocat 620 PLT w/o correction',zorder=0)
# k= AndyPLT ['DissOxygen'].to_numpy().reshape(-1,1)
# m= AndyPLT ['pH'].to_numpy().reshape(-1,1)
# mockk = np.arange(AndyPLT['hydrocatDissOxygen'].min(), AndyPLT['hydrocatDissOxygen'].max(), 0.1).reshape(-1, 1)
# mockm = model.predict(mockk)
# ax.fill_between(mockk[:,0], mockm[:,0],mockm[:,0] + 2*delt, color = 'c', alpha = 0.2)
# ax.fill_between(mockk[:,0], mockm[:,0],mockm[:,0] - 2*delt, color = 'c', alpha=0.2) 
# ax.set_xlabel("Dissolved Oxygen")
# ax.set_ylabel("pH")
# (m,b) = np.plotyfit(x,y,1)
# lp=np.polyval([m,b],x)
# plt.plot(x,lp)
# plt.grid(True)

# %%
fig,ax=plt.subplots(figsize=[25,17])
ax.scatter(labGB['DateTime'],labGB['pH'], color = 'crimson', marker = 'D',edgecolors='black', s =80, label = 'Lab GB', zorder = 5)
ax.scatter(labPLT['DateTime'], labPLT['pH'], color = 'mediumseagreen', marker = 'H',edgecolors='black',s= 80, label = 'Lab PLT', zorder = 5)
ax.plot(pH_data['DateTime'].to_numpy(),pH_data['External pH (pH)'].to_numpy(), color = 'black',label = 'SeaFET', zorder=4)
ax.plot(MV['DateTime'].to_numpy(),MV['pH'].to_numpy(), color = 'lightcoral',label = 'NBFSM - MV', zorder=3)
ax.plot(QP['DateTime'].to_numpy(),QP['pH'].to_numpy(), color = 'gold',label = 'NBFSM - QP', zorder=3)
ax.plot(AndyPLT['Time'].to_numpy(), AndyPLT['pH'].to_numpy(), color = 'orange', label = 'Hydrocat 720',zorder = 1)
ax.plot(AndyGB['Time'].to_numpy(), AndyGB['pH'].to_numpy(), color = 'purple', label = 'Hydrocat 620', zorder=0)
# ax.plot(df720['DateTime'].to_numpy(),df720['pH total'].to_numpy(),color ='orange', label = 'sensor 720',zorder=2)
# ax.plot(df620['DateTime'].to_numpy(),df620['pH total'].to_numpy(),color ='purple', label = 'sensor 620',zorder=2)
ax.xaxis.set_major_locator(mdates.MonthLocator(interval=1))
ax.tick_params('x',labelsize = 12, labelrotation = 90)
ax.tick_params('y',labelsize = 12)
ax.legend(fontsize = 12)
ax.set_xlabel('Year-Month')
ax.set_ylabel('pH')
# Out:
# Text(0, 0.5, 'pH')

# %% [markdown]
# plot date and ph

# %% [markdown]
# Removing outliersss using stdev

# %% [markdown]
# Hydrocat 620 sensor outiler removal + new graph without outilers

# %%
def rmoutliers_STD(dataframe, var): 
    stdev= dataframe[var].std()
    mean = dataframe[var].mean()
    lower=mean-2*stdev
    upper= mean+2*stdev
    
    for ind in dataframe.index: 
        if dataframe[var][ind]> upper: 
            dataframe=dataframe.drop(ind) 
        elif dataframe[var][ind] <lower: 
            dataframe = dataframe.drop(ind) 
    dv=dataframe.reset_index(drop=True)
    return dv

# %%
hydrocat620_STD = rmoutliers_STD(df620, 'pH total')

# %%
fig,ax = plt.subplots(figsize=[10,10])
ax.plot(df620['DateTime'].to_numpy(), df620['pH total'].to_numpy(), color = 'blue', label = 'Hydrocat PLT 620')
ax.plot(hydrocat620_STD['DateTime'].to_numpy(), hydrocat620_STD['pH total'].to_numpy(), color = 'red', label = 'Hydrocat PLT 620 NO OUTLIERS')
ax.xaxis.set_major_locator(mdates.MonthLocator(interval=1))
ax.tick_params('x',labelsize = 12, labelrotation = 90)
ax.tick_params('y',labelsize = 12)
ax.legend(fontsize = 12)
ax.set_xlabel('Year-Month', fontsize = 12)
# Out:
# Text(0.5, 0, 'Year-Month')

# %%
x = hydrocat620_STD['hydrocatDissOxygen'].to_numpy().reshape(-1, 1)
y = hydrocat620_STD['pH total'].to_numpy().reshape(-1, 1)
model = LinearRegression().fit(x, y)
y_pred = model.predict(x)
delt = mean_absolute_error(y, y_pred)

# this line predicts y (i.e. pH) based on the input x (i.e. dissolved oxygen)
# in other words, these are the y values of the linear model
# y_pred = model.predict(x)

# added the predicted pH to the dataset
hydrocat620_STD['pH_pred'] = y_pred
# # added the difference between the predicted pH and the actual pH
hydrocat620_STD['pH - pH_pred'] = y - y_pred
# # selecting the part of the dataset where the diff between predicted and actual is greater than 2 stds

STD620 = hydrocat620_STD.where(np.abs(hydrocat620_STD['pH - pH_pred']) < 2*delt).dropna()
STD620 = STD620.reset_index(drop=True)
fig, ax = plt.subplots(figsize = [10,10])


ax.scatter(x,y)
plt.title ('Hydrocat 620 pH In Relation to Dissolved Oxygen')
# x by the predicted y
ax.plot(x,y_pred, color = 'c', zorder = 3)
# ax.plot(x,y, color = 'purple')
# add eerror lines
# ax.plot(x,y_pred - 2*delt, color = 'red')
# ax.plot(x,y_pred + 2*delt, color = 'red')
mockX = np.arange(hydrocat620_STD['hydrocatDissOxygen'].min(), hydrocat620_STD['hydrocatDissOxygen'].max(), 0.1).reshape(-1, 1)
mockY = model.predict(mockX)
ax.fill_between(mockX[:,0], mockY[:,0],mockY[:,0] + 2*delt, color = 'r', alpha = 0.2)
ax.fill_between(mockX[:,0], mockY[:,0],mockY[:,0] - 2*delt, color = 'r', alpha = 0.2)
ax.set_xlabel('Dissolved Oxygen')
ax.set_ylabel('pH')
# Out:
# Text(0, 0.5, 'pH')

# %%
fig, ax = plt.subplots(figsize = [10,10])
plt.scatter(hydrocat620_STD['DateTime'].to_numpy(), hydrocat620_STD['pH total'].to_numpy(), color = 'r')
plt.scatter(STD620['DateTime'].to_numpy(), STD620['pH total'].to_numpy(), color='b')

# %%
def rmoutliers_STD4(dataframe, var): 
    stdev= dataframe[var].std()
    mean = dataframe[var].mean()
    lower=mean-2*stdev
    upper= mean+2*stdev
    
    for ind in dataframe.index: 
        if dataframe[var][ind]> upper: 
            dataframe=dataframe.drop(ind) 
        elif dataframe[var][ind] <lower: 
            dataframe = dataframe.drop(ind) 
    dv=dataframe.reset_index(drop=True)
    return dv

# %%
hydrocat720_STD = rmoutliers_STD4(df720, 'pH total')

# %%
fig,ax = plt.subplots(figsize=[10,10])
ax.plot(df720['DateTime'].to_numpy(), df720['pH total'].to_numpy(), color = 'blue', label = 'Hydrocat GB 720')
ax.plot(hydrocat720_STD['DateTime'].to_numpy(), hydrocat720_STD['pH total'].to_numpy(), color = 'red', label = 'Hydrocat GB 720 NO OUTLIERS')
ax.xaxis.set_major_locator(mdates.MonthLocator(interval=1))
ax.tick_params('x',labelsize = 12, labelrotation = 90)
ax.tick_params('y',labelsize = 12)
ax.legend(fontsize = 12)
ax.set_xlabel('Year-Month', fontsize = 12)
# Out:
# Text(0.5, 0, 'Year-Month')

# %% [markdown]
# New TimeSeries after outlier removal

# %%
fig,ax=plt.subplots(figsize=[35,15])
ax.scatter(labGB['DateTime'],labGB['pH'], color = 'crimson', marker = 'D',edgecolors='black', s =100, label = 'Lab GB', zorder = 5)
# ax.scatter(labPLT['DateTime'], labPLT['pH'], color = 'mediumseagreen', marker = 'H',edgecolors='black',s= 100, label = 'Lab PLT', zorder = 5)
# ax.plot(seaFET_STD['DateTime'].to_numpy(),seaFET_STD ['External pH (pH)'].to_numpy(), color = 'black',label = 'SeaFET', zorder=4)
ax.plot(MV_STD['DateTime'].to_numpy(),MV_STD['pH'].to_numpy(), color = 'lightcoral',label = 'NBFSM - MV', zorder=3)
# ax.plot(QP_STD['DateTime'].to_numpy(),QP_STD['pH'].to_numpy(), color = 'gold',label = 'NBFSM - QP', zorder=3)
# ax.plot(hydrocat620_STD['DateTime'].to_numpy(), hydrocat620_STD['pH total'].to_numpy(), color = 'orange', label = 'Hydrocat 620 - PLT',zorder = 1)
ax.plot(hydrocat720_STD['DateTime'].to_numpy(), hydrocat720_STD['pH total'].to_numpy(), color = 'purple', label = 'Hydrocat 720 - GB', zorder=0)


ax.xaxis.set_major_locator(mdates.MonthLocator(interval=1))
ax.tick_params('x',labelsize = 12, labelrotation = 90)
ax.tick_params('y',labelsize = 12)
ax.legend(fontsize = 12)
ax.set_xlabel('Year-Month')
ax.set_ylabel('pH')
plt.title ('pH In Relation to Date Without Outliers - GB')
# Out:
# Text(0.5, 1.0, 'pH In Relation to Date Without Outliers - GB')

# %%
fig,ax=plt.subplots(figsize=[30,15])
# ax.scatter(labGB['DateTime'],labGB['pH'], color = 'crimson', marker = 'D',edgecolors='black', s =100, label = 'Lab GB', zorder = 5)
ax.scatter(labPLT['DateTime'], labPLT['pH'], color = 'mediumseagreen', marker = 'H',edgecolors='black',s= 100, label = 'Lab PLT', zorder = 5)
ax.plot(seaFET_STD['DateTime'].to_numpy(),seaFET_STD ['External pH (pH)'].to_numpy(), color = 'black',label = 'SeaFET', zorder=4)
# ax.plot(MV_STD['DateTime'].to_numpy(),MV_STD['pH'].to_numpy(), color = 'lightcoral',label = 'NBFSM - MV', zorder=3)
ax.plot(QP_STD['DateTime'].to_numpy(),QP_STD['pH'].to_numpy(), color = 'gold',label = 'NBFSM - QP', zorder=3)
ax.plot(hydrocat620_STD['DateTime'].to_numpy(), hydrocat620_STD['pH total'].to_numpy(), color = 'orange', label = 'Hydrocat 620 - PLT',zorder = 1)
# ax.plot(hydrocat720_STD['DateTime'].to_numpy(), hydrocat720_STD['pH total'].to_numpy(), color = 'purple', label = 'Hydrocat 720 - GB', zorder=0)


ax.xaxis.set_major_locator(mdates.MonthLocator(interval=1))
ax.tick_params('x',labelsize = 12, labelrotation = 90)
ax.tick_params('y',labelsize = 12)
ax.legend(fontsize = 12)
ax.set_xlabel('Year-Month')
ax.set_ylabel('pH')
plt.title ('pH In Relation to Date Without Outliers - PLT')
# Out:
# Text(0.5, 1.0, 'pH In Relation to Date Without Outliers - PLT')

# %%
fig,ax=plt.subplots(figsize=[35,15])
ax.scatter(labGB['DateTime'],labGB['pH'], color = 'crimson', marker = 'D',edgecolors='black', s =100, label = 'Lab GB', zorder = 5)
ax.scatter(labPLT['DateTime'], labPLT['pH'], color = 'mediumseagreen', marker = 'H',edgecolors='black',s= 100, label = 'Lab PLT', zorder = 5)
ax.plot(seaFET_STD['DateTime'].to_numpy(),seaFET_STD ['External pH (pH)'].to_numpy(), color = 'black',label = 'SeaFET', zorder=4)
ax.plot(MV_STD['DateTime'].to_numpy(),MV_STD['pH'].to_numpy(), color = 'lightcoral',label = 'NBFSM - MV', zorder=3)
ax.plot(QP_STD['DateTime'].to_numpy(),QP_STD['pH'].to_numpy(), color = 'gold',label = 'NBFSM - QP', zorder=3)
ax.plot(hydrocat620_STD['DateTime'].to_numpy(), hydrocat620_STD['pH total'].to_numpy(), color = 'orange', label = 'Hydrocat 620 - PLT',zorder = 1)
ax.plot(hydrocat720_STD['DateTime'].to_numpy(), hydrocat720_STD['pH total'].to_numpy(), color = 'purple', label = 'Hydrocat 720 - GB', zorder=0)


ax.xaxis.set_major_locator(mdates.MonthLocator(interval=1))
ax.tick_params('x',labelsize = 12, labelrotation = 90)
ax.tick_params('y',labelsize = 12)
ax.legend(fontsize = 12)
ax.set_xlabel('Year-Month')
ax.set_ylabel('pH')
plt.title ('pH In Relation to Date Without Outliers')
# Out:
# Text(0.5, 1.0, 'pH In Relation to Date Without Outliers')

# %% [markdown]
# Gettig value difference between bottle and sensor

# %%
labGB
# Out:
#            Sample            Time Location    depth  TA Temp (degC)   TA (uM)  \
# 5     GB B 9/9/22    9/9/22 11:30       GB  surface            21.3  1957.870
# 6     GB A 9/9/22    9/9/22 11:30       GB  surface            21.3  1955.840
# 7    GB B 9/20/22   9/20/22 11:30       GB  surface            21.3  2051.600
# 8    GB A 9/20/22   9/20/22 11:30       GB  surface            21.3  2051.930
# 9   GB A 10/25/22  10/25/22 11:30       GB  surface            21.3  2047.245
# 10  GB B 10/25/22  10/25/22 11:30       GB  surface            21.3  2043.310
# 11   GB A 11/9/22   11/9/22 11:30       GB  surface            21.3  2079.940
# 12   GB B 11/9/22   11/9/22 11:30       GB  surface            21.3  2080.755
# 24          GB169    2/1/23 11:30       GB                     20.8  1651.600
# 47          GB196   3/22/23 10:15       GB  surface            21.3  2025.780
#
#     DIC Temp (degC)  DIC (uM)  Salinity            DateTime    P      rho_DIC  \
# ...

# %%
MV
# Out:
#        Site Agency      Date    Time               C    Temp      SpC  \
# 2353   B6-S   gsovs  05/25/22  12:15   5/25/22 12:15  18.498  45164.1
# 2354   B6-S   gsovs  05/25/22  12:30   5/25/22 12:30  18.452  45257.7
# 2355   B6-S   gsovs  05/25/22  12:45   5/25/22 12:45  18.399  45304.7
# 2356   B6-S   gsovs  05/25/22  13:00   5/25/22 13:00  18.376  45345.2
# 2357   B6-S   gsovs  05/25/22  13:15   5/25/22 13:15  18.230    45431
# ...     ...     ...       ...    ...             ...     ...      ...
# 19722  B6-S   gsovs  11/22/22  10:30  11/22/22 10:30   8.814  46579.1
# 19723  B6-S   gsovs  11/22/22  10:45  11/22/22 10:45   8.680  46538.9
# 19724  B6-S   gsovs  11/22/22  11:00  11/22/22 11:00   8.646  46527.2
# 19725  B6-S   gsovs  11/22/22  11:15  11/22/22 11:15   8.582    46492
# 19726  B6-S   gsovs  11/22/22  11:30  11/22/22 11:30   8.586  46472.2
#
#        Salinity    DO% DO Conc  Depth    pH            DateTime  pH total
# ...

# %% [markdown]
# Comparing Bottle samples to Sensors

# %% [markdown]
# # Here you used an old code of mine to plot the anomalies
# That code doesn't work as intended (which is my fault).

# %%
fig,ax = plt.subplots(nrows = 2, figsize=[50,30])
fig.tight_layout(pad = 30)

PLTzos = np.zeros(len(labPLT['DateTime']))

ax[0].scatter(labPLT['DateTime'], labPLT['pH'] -labPLT['sensor620 ph'], color = 'red', edgecolor = 'black',linewidths = 5,s = 700, label = 'PLT Bottle Samples Minus Jamestown Buoy 620', zorder = 3)
ax[0].scatter(labGB['DateTime'], labGB['pH']- labGB['sensor720 ph'], color = 'blue', edgecolor = 'black',linewidths = 5,s = 700, label = 'GB Bottle Samples Minus GB Buoy 720', zorder = 3)
ax[0].plot(labPLT['DateTime'].to_numpy(), PLTzos, '--k')

ax[1].scatter(labPLT['DateTime'], labPLT['pH'] - labPLT['sensor720 ph'], color = 'red', edgecolor = 'black', linewidths = 5,s = 700, label = 'PLT Bottle Samples Minus GB Buoy 720', zorder = 3)
ax[1].scatter(labGB['DateTime'], labGB['pH']- labGB['sensor620 ph'], color = 'blue', edgecolor = 'black', linewidths = 5,s = 700, label = 'GB Bottle Samples Minus Jamestown Buoy 620', zorder = 3)
ax[1].plot(labPLT['DateTime'].to_numpy(), PLTzos, '--k')

ax[0].xaxis.set_major_locator(mdates.MonthLocator(interval=1))
ax[0].tick_params('x',labelsize = 30, labelrotation = 90)
ax[0].tick_params('y',labelsize = 36)
ax[0].legend(loc = 'lower left', fontsize = 36)
ax[0].set_xlabel('Year-Month', fontsize = 36)
ax[0].set_ylabel('pH [total scale]', fontsize = 36)

ax[1].xaxis.set_major_locator(mdates.MonthLocator(interval=1))
ax[1].tick_params('x',labelsize = 30, labelrotation = 90)
ax[1].tick_params('y',labelsize = 36)
ax[1].legend(loc = 'upper right', fontsize = 36)
ax[1].set_xlabel('Year-Month', fontsize = 36)
ax[1].set_ylabel('pH [total scale]', fontsize = 36)

ax[0].annotate('Buoys Overestimate pH', xy=(labPLT['DateTime'].iloc[len(labPLT)-1], 0), xytext=(labPLT['DateTime'].loc[30], -0.05), fontsize = 30)
ax[0].annotate('Buoys Underestimate pH', xy=(labPLT['DateTime'].iloc[len(labPLT)-1], 0), xytext=(labPLT['DateTime'].loc[30], +0.05), fontsize = 30)

ax[1].annotate('Buoys Overestimate pH', xy=(labPLT['DateTime'].iloc[len(labPLT)-1], 0), xytext=(labPLT['DateTime'].loc[30], -0.05), fontsize = 30)
ax[1].annotate('Buoys Underestimate pH', xy=(labPLT['DateTime'].iloc[len(labPLT)-1], 0), xytext=(labPLT['DateTime'].loc[30], +0.05), fontsize = 30)
# Out:
# Text(2023-02-06 12:30:00, 0.05, 'Buoys Underestimate pH')

# %% [markdown]
# # here is an updated version of how i plotted the anomalies
# ## first i change datetime to a timestamp object

# %%
# unsure if df620 and df720 have had outliers dropped yet but i am just 
# using them for this example
df620["time"] = pd.to_datetime(df620['DateTime'])
df720["time"] = pd.to_datetime(df720['DateTime'])
MV["time"] = pd.to_datetime(MV['DateTime'])
QP["time"] = pd.to_datetime(QP['DateTime'])
# i also have not checked that all of these datasets are in UTC time
# so check that before you run this yourself
labPLT["time"] = pd.to_datetime(labPLT['DateTime'])
labGB["time"] = pd.to_datetime(labGB['DateTime'])

# %% [markdown]
# ## Next i merge 2 dataframes i want to compare by time
# I used `pd.merge_asof()` which requires timestamp objects. this is why i converted things to timestamp objects above. This function finds where the 2 datasets have timestamps that are similar (within a certain tolerance) and combine rows with the same time.
#
# Here I want to compare hydrocat620 with the PLT lab samples. Note that there are a lot of NaN values.

# %%
PLT_hydro620 = pd.merge_asof(labPLT, df620, on="time",tolerance = pd.Timedelta("5m"))
PLT_hydro620
# Out:
#             Sample               Time Location    depth  TA Temp (degC)  \
# 0      PLT 6/13/22       6/13/22 7:30      PLT  surface            21.3
# 1      PLT 6/28/22       6/28/22 7:30      PLT  surface            21.3
# 2      PLT 7/19/22       7/19/22 7:30      PLT  surface            21.2
# 3      PLT 7/26/22       7/26/22 7:30      PLT  surface            21.2
# 4    PLT223 8/8/22        8/8/22 7:30      PLT  surface            21.3
# 5    NB224 8/15/22       8/15/22 7:30      PLT  surface            21.2
# 6            NB215       8/22/22 7:30      PLT  surface            21.2
# 7   PLT233 8/26/22       8/26/22 7:30      PLT  surface            21.3
# 8      PLT 9/19/22       9/19/22 7:30      PLT  surface            21.2
# 9            NB207       11/7/22 7:30      PLT   bottom            20.7
# 10           NB204       11/7/22 7:30      PLT  surface            20.6
# 11           NB143      11/14/22 7:30      PLT   bottom            20.7
# ...

# %% [markdown]
# To reduce the number of NaN values, I relaxed my time tolerance from `tolerance = pd.Timedelta("5m")` to `tolerance = pd.Timedelta("45m")`. There is an argument that 45 minutes is too relaxed of a tolerance, but the point is you can change the tolerance to anything.

# %%
PLT_hydro620 = pd.merge_asof(labPLT, df620, on="time",tolerance = pd.Timedelta("45m"))
PLT_hydro620
# Out:
#             Sample               Time Location    depth  TA Temp (degC)  \
# 0      PLT 6/13/22       6/13/22 7:30      PLT  surface            21.3
# 1      PLT 6/28/22       6/28/22 7:30      PLT  surface            21.3
# 2      PLT 7/19/22       7/19/22 7:30      PLT  surface            21.2
# 3      PLT 7/26/22       7/26/22 7:30      PLT  surface            21.2
# 4    PLT223 8/8/22        8/8/22 7:30      PLT  surface            21.3
# 5    NB224 8/15/22       8/15/22 7:30      PLT  surface            21.2
# 6            NB215       8/22/22 7:30      PLT  surface            21.2
# 7   PLT233 8/26/22       8/26/22 7:30      PLT  surface            21.3
# 8      PLT 9/19/22       9/19/22 7:30      PLT  surface            21.2
# 9            NB207       11/7/22 7:30      PLT   bottom            20.7
# 10           NB204       11/7/22 7:30      PLT  surface            20.6
# 11           NB143      11/14/22 7:30      PLT   bottom            20.7
# ...

# %% [markdown]
# I can do the same thing with the other datasets comparing
# * Buoy 620 --> PLT
#
# * Buoy 720 --> GB
#
# * MV --> GB
#
# * QP --> PLT
#
# These comparisons are based on how close the sensor site is to each sampling site.

# %%
GB_hydro720 = pd.merge_asof(labGB, df720, on="time",tolerance = pd.Timedelta("30m"))
GB_MV = pd.merge_asof(labGB, MV, on="time",tolerance = pd.Timedelta("30m"))
PLT_QP = pd.merge_asof(labPLT, QP, on="time",tolerance = pd.Timedelta("30m"))

# %%
PLT_QP.keys()
# Out:
# Index(['Sample', 'Time_x', 'Location', 'depth', 'TA Temp (degC)', 'TA (uM)',
#        'DIC Temp (degC)', 'DIC (uM)', 'Salinity_x', 'DateTime_x', 'P',
#        'rho_DIC', 'rho_TA', 'DIC (umol/kg)', 'TA (umol/kg)', 'pH_x',
#        'sensor620 ph', 'sensor720 ph', 'time', 'Site', 'Agency ', 'Date ',
#        'Time_y', 'C', 'Temp', 'SpC', 'Salinity_y', 'DO%', 'DO Conc', 'Depth',
#        'pH_y', 'DateTime_y', 'pH total'],
#       dtype='object')

# %% [markdown]
# I can then plot. I have chosen to define my anomalies as the sensor pH minus the lab pH: `PLT_QP['pH total'] - PLT_QP['pH_x']`.
#
# I used the function `ax.fill_between()` to mark the precision of the sensor.

# %%
fig, ax = plt.subplots(figsize = [20,10])

ax.scatter(PLT_QP['time'],PLT_QP['pH total'] - PLT_QP['pH_x'], 
           marker = 'o', s = 100, edgecolors = 'k', facecolor = 'pink', label = 'NBFSMN QP')

ax.fill_between(PLT_hydro620['time'], -0.1, 0.1, color = 'g', alpha = 0.2)
# ax.fill_between(mockX[:,0], mockY[:,0],mockY[:,0] - E*delt, color = 'r', alpha = 0.2)

ax.xaxis.set_major_locator(mdates.MonthLocator(interval=1))
ax.tick_params('x',labelsize = 12, labelrotation = 90)
ax.tick_params('y',labelsize = 12)
ax.legend(fontsize = 12)
ax.set_xlabel('Year-Month', fontsize = 12)
ax.set_ylabel('Sensor pH - Lab Sample pH', fontsize = 12)
ax.set_ylim([-0.5,0.5])
# Out:
# (-0.5, 0.5)

# %% [markdown]
# # So I think something that is giving you problems/will give you problems
# Is how you loaded many of these datasets multiple times and it has become hard to keep up with which dataset is which. I would recommend using this opportunity to start a whole new notebook, load each dataset once, write over the previous datasets each time you update/drop outliers. It also might be help to more thoroughly comment your code to say to yourself "hey this dataset is from xyz and has a,b,and c data. my headers are *this*" just to help you keep track of everything
