# %%
import re
import time

import requests
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import math

URL = 'https://api.riddc.brown.edu/telemetry/Buoy-620/CoreMetrics/range?start=2023-03-27T12:00:00.000Z&end=2023-04-07T12:45:00.000Z'

r = requests.get(URL)
JSON = r.json()
df = pd.DataFrame(JSON['MetData'])
    

df['DateTime'] = np.zeros(len(df['TmStamp']))
for ind in df.index:
    df['DateTime'][ind] = datetime.strptime(df['TmStamp'][ind], '%Y-%m-%dT%H:%M:%S.%fZ') 

df
# Out:
# /var/folders/9k/5r38tm8d21g6nm3w9rchrd6m0000gn/T/ipykernel_29466/1033138607.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['DateTime'][ind] = datetime.strptime(df['TmStamp'][ind], '%Y-%m-%dT%H:%M:%S.%fZ')
#                        TmStamp         metdataStart  avgWindSpeed  avgWindDir  \
# 0     2023-03-27T12:00:00.000Z  03/27/2023 12:00:00       2.51260     74.3263
# 1     2023-03-27T12:10:00.000Z  03/27/2023 12:10:00       2.97957     71.1170
# 2     2023-03-27T12:20:00.000Z  03/27/2023 12:20:00       2.74269     56.0782
# 3     2023-03-27T12:30:00.000Z  03/27/2023 12:30:00       2.76095     59.0503
# 4     2023-03-27T12:40:00.000Z  03/27/2023 12:40:00       2.50226     56.4225
# ...                        ...                  ...           ...         ...
# 1300  2023-04-07T12:00:00.000Z  04/07/2023 12:00:00       6.89818    281.1050
# 1301  2023-04-07T12:10:00.000Z  04/07/2023 12:10:00       6.62318    283.1690
# 1302  2023-04-07T12:20:00.000Z  04/07/2023 12:20:00       6.39250    295.8300
# 1303  2023-04-07T12:30:00.000Z  04/07/2023 12:30:00       6.89421    289.4570
# 1304  2023-04-07T12:40:00.000Z  04/07/2023 12:40:00       6.98475    294.2580
#
#       gustWindSpeed  gustWindDir  maximetTemperature  maximetPressure  \
# 0           3.02656      75.3414                 8.7           1017.0
# 1           3.76654      75.3372                 8.8           1017.0
# 2           3.50632      52.0238                 8.9           1016.7
# 3           3.69068      70.4497                 9.1           1016.6
# 4           3.58722      62.7351                 9.3           1016.5
# ...             ...          ...                 ...              ...
# 1300        9.29040     283.5830                11.8           1022.5
# 1301        9.16148     270.6770                12.1           1022.3
# 1302        8.57547     306.2690                12.4           1022.2
# 1303        9.82344     297.4580                12.5           1022.1
# 1304       10.75730     286.1070                12.8           1022.1
#
#       maximetHumidity  maximetPrecipitation  maximetSolar             DateTime
# 0                  58                   0.0           801  2023-03-27 12:00:00
# 1                  57                   0.0           816  2023-03-27 12:10:00
# 2                  56                   0.0           826  2023-03-27 12:20:00
# 3                  52                   0.0           832  2023-03-27 12:30:00
# 4                  53                   0.0           838  2023-03-27 12:40:00
# ...               ...                   ...           ...                  ...
# 1300               45                   0.0           430  2023-04-07 12:00:00
# 1301               41                   0.0           462  2023-04-07 12:10:00
# 1302               37                   0.0           464  2023-04-07 12:20:00
# 1303               40                   0.0           512  2023-04-07 12:30:00
# 1304               36                   0.0           565  2023-04-07 12:40:00
#
# [1305 rows x 12 columns]

# %%
isinstance(df['avgWindDir'][1], float)
# Out:
# True

# %%
for k in df.keys():
    for ind in df.index:
        if isinstance(df[k][ind], float) or isinstance(df[k][ind], int):
            if math.isnan(df[k][ind]):
                df = df.drop(ind)
                df = df.reset_index(drop=True)

# %%
# %cd '/Users/akbaskind/Documents/Python Scripts/phyto'
# %run PLT.py
# Out:
# /Users/akbaskind/Documents/Python Scripts/phyto

# %%
    def get_buoy(start_date, end_date, buoy, sensor):
        """
        Retrieve Hydrocat data from Andy Davies' sensors using the API
        Drop 0 or negative pH values
        Time zone kept in UTC
        Convert pH from NBS to total scale using PyCO2SYS
        
        INPUTS:
            - start_date: date as a string, formatted as YYYY-MM-DD
            - end_date: date as a string, formatted as YYYY-MM-DD
            - buoy: Jamestown/620/PLT or 720/Greenwich Bay/BG
        
        RETURNS pandas DataFrame
        
        Add '%cd directory' and '%run PLT.py' to your script, making sure the path is correct
        """
        import re
        import time
        import PyCO2SYS as pyco2
        import requests
        import pandas as pd
        import numpy as np
        from datetime import datetime, timedelta
        import math
    
        # Check that start and end dates are formatted correctly
        # Return error message if format is wrong
        matched_start = re.match("\d{4}-\d{2}-\d{2}", start_date)
        matched_end = re.match("\d{4}-\d{2}-\d{2}", end_date)
        if bool(not matched_start) or bool(not matched_end):
            print('Error: Input date must be a string of the form YYYY-MM-DD')
            return
    
        # Check that start date is before end date
        # Switch dates if start date after end date
        a = time.strptime(start_date, '%Y-%m-%d')
        b = time.strptime(end_date, '%Y-%m-%d')
        if a > b:
            start = start_date
            start_date = end_date
            end_date = start
    
        # create URL string using start date, end date, and buoy
        if buoy == 'Jamestown' or buoy == '620' or buoy == 'PLT': 
            URL = 'https://api.riddc.brown.edu/telemetry/Buoy-620/CoreMetrics/range?start=' + start_date + '&end=' + end_date
        elif buoy == 'Greenwich Bay' or buoy == '720' or buoy == 'GB': 
            URL = 'https://api.riddc.brown.edu/telemetry/Buoy-720/CoreMetrics/range?start=' + start_date + '&end=' + end_date
        else:
            print('Buoy options are 620 for Jamestown/PLT or 720 for Greenwich Bay/GB.')
            return 
        
        if sensor != 'MetData' or sensor != 'PAR' or sensor != 'SUNA':
            print("Please choose either the MetDada, PAR, or SUNA sensor."
    
        # Ingest data from API
        r = requests.get(URL)
        JSON = r.json()
        df = pd.DataFrame(JSON[sensor])
    
        # Drop 0 and negative values and nan values
        for k in df.keys():
            for ind in df.index:
                if isinstance(df[k][ind], float) or isinstance(df[k][ind], int):
                    if math.isnan(df[k][ind]):
                        df = df.drop(ind)
                        df = df.reset_index(drop=True)
            
        # Get DateTime object from TmStamp string 
        # Keep timezone in UTC
        df['DateTime'] = np.zeros(len(df['TmStamp']))
        for ind in df.index:
            df['DateTime'][ind] = datetime.strptime(df['TmStamp'][ind], '%Y-%m-%dT%H:%M:%S.%fZ') 
    
        return df
# Out:
#   File "/var/folders/9k/5r38tm8d21g6nm3w9rchrd6m0000gn/T/ipykernel_29466/1454826535.py", line 56
#     r = requests.get(URL)
#     ^
# SyntaxError: invalid syntax

# %%
PAR620 = PLT.get_buoy('2021-01-01', '2023-06-10', 'PLT', 'PAR')
hydrocat620 = PLT.get_hydrocat('2021-01-01', '2023-06-10', 'PLT')
Met620 = PLT.get_buoy('2021-01-01', '2023-06-10', 'PLT', 'MetData')
# Out:
# /Users/akbaskind/Documents/Python Scripts/phyto/PLT.py:412: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Get DateTime object from TmStamp string
# /Users/akbaskind/Documents/Python Scripts/phyto/PLT.py:77: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['DateTime'][ind] = datetime.strptime(df['TmStamp'][ind], '%Y-%m-%dT%H:%M:%S.%fZ')
# /Users/akbaskind/Documents/Python Scripts/phyto/PLT.py:412: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Get DateTime object from TmStamp string

# %%
PAR620
# Out:
#                         TmStamp             parStart  PARcalibrated  \
# 0      2021-06-08T17:32:01.200Z                 None     418.244000
# 1      2021-06-08T17:47:01.200Z                 None     326.711000
# 2      2021-06-08T18:02:01.200Z                 None     263.431000
# 3      2021-06-08T18:17:01.200Z                 None     224.768000
# 4      2021-06-08T18:32:01.200Z                 None     195.828000
# ...                         ...                  ...            ...
# 62627  2023-06-09T22:47:01.000Z  06/09/2023 22:45:00      -0.032488
# 62628  2023-06-09T23:02:01.000Z  06/09/2023 23:00:00      -0.050095
# 62629  2023-06-09T23:17:01.000Z  06/09/2023 23:15:00      -0.044892
# 62630  2023-06-09T23:32:01.000Z  06/09/2023 23:30:00      -0.046530
# 62631  2023-06-09T23:47:01.000Z  06/09/2023 23:45:00      -0.043020
#
#                                DateTime
# 0      2021-06-08 17:32:01.200000+00:00
# 1      2021-06-08 17:47:01.200000+00:00
# 2      2021-06-08 18:02:01.200000+00:00
# 3      2021-06-08 18:17:01.200000+00:00
# 4      2021-06-08 18:32:01.200000+00:00
# ...                                 ...
# 62627         2023-06-09 22:47:01+00:00
# 62628         2023-06-09 23:02:01+00:00
# 62629         2023-06-09 23:17:01+00:00
# 62630         2023-06-09 23:32:01+00:00
# 62631         2023-06-09 23:47:01+00:00
#
# [62632 rows x 4 columns]

# %%
hydrocat620
# Out:
#                         TmStamp        hydrocatStart  hydrocatTemperature  \
# 0      2021-05-27T10:25:43.600Z                 None              21.2578
# 1      2021-05-27T10:40:43.600Z                 None              21.9588
# 2      2021-05-27T10:55:43.600Z                 None              22.8357
# 3      2021-05-27T11:10:44.000Z                 None              23.7191
# 4      2021-05-27T11:25:43.600Z                 None              24.5672
# ...                         ...                  ...                  ...
# 49167  2023-06-09T22:46:29.000Z  06/09/2023 22:45:00              16.4457
# 49168  2023-06-09T23:01:29.000Z  06/09/2023 23:00:00              16.4552
# 49169  2023-06-09T23:16:29.000Z  06/09/2023 23:15:00              16.4764
# 49170  2023-06-09T23:31:30.600Z  06/09/2023 23:30:00              16.4258
# 49171  2023-06-09T23:46:29.000Z  06/09/2023 23:45:00              16.4393
#
#        hydrocatConductivity  hydrocatDissOxygen  hydrocatSalinity  \
# 0                    0.0003               8.652            0.0105
# 1                    0.0003               8.613            0.0108
# 2                    0.0003               8.504            0.0111
# 3                    0.0004               8.366            0.0114
# 4                    0.0003               8.246            0.0118
# ...                     ...                 ...               ...
# 49167               38.0324               7.887           29.4882
# 49168               38.0302               7.942           29.4793
# 49169               38.0719               7.956           29.4996
# 49170               37.8790               7.995           29.3706
# 49171               37.9020               7.943           29.3805
#
#        hydrocatFluorescence  hydrocatTurbidity  hydrocatPH  \
# 0              2.527630e-38              9.550        6.44
# 1              2.527630e-38              9.443        6.48
# 2              2.527630e-38              9.377        6.50
# 3              2.527630e-38              9.314        6.50
# 4              2.527630e-38              9.243        6.51
# ...                     ...                ...         ...
# 49167          1.100000e-02             18.401        7.32
# 49168          1.000000e-02             18.667        7.34
# 49169          1.100000e-02             18.475        7.46
# 49170          1.200000e-02             18.153        7.53
# 49171          1.100000e-02             18.298        7.38
#
#                                DateTime  pH total
# 0      2021-05-27 10:25:43.600000+00:00  6.282238
# 1      2021-05-27 10:40:43.600000+00:00  6.321346
# 2      2021-05-27 10:55:43.600000+00:00  6.340228
# 3             2021-05-27 11:10:44+00:00  6.339099
# 4      2021-05-27 11:25:43.600000+00:00  6.348012
# ...                                 ...       ...
# 49167         2023-06-09 22:46:29+00:00  7.194243
# 49168         2023-06-09 23:01:29+00:00  7.214214
# 49169         2023-06-09 23:16:29+00:00  7.334201
# 49170  2023-06-09 23:31:30.600000+00:00  7.404132
# 49171         2023-06-09 23:46:29+00:00  7.254119
#
# [49172 rows x 11 columns]

# %%
df2 = PAR620[['DateTime','PARcalibrated']]
df2
# Out:
#                                DateTime  PARcalibrated
# 0      2021-06-08 17:32:01.200000+00:00     418.244000
# 1      2021-06-08 17:47:01.200000+00:00     326.711000
# 2      2021-06-08 18:02:01.200000+00:00     263.431000
# 3      2021-06-08 18:17:01.200000+00:00     224.768000
# 4      2021-06-08 18:32:01.200000+00:00     195.828000
# ...                                 ...            ...
# 62627         2023-06-09 22:47:01+00:00      -0.032488
# 62628         2023-06-09 23:02:01+00:00      -0.050095
# 62629         2023-06-09 23:17:01+00:00      -0.044892
# 62630         2023-06-09 23:32:01+00:00      -0.046530
# 62631         2023-06-09 23:47:01+00:00      -0.043020
#
# [62632 rows x 2 columns]

# %%
df1 = hydrocat620[['DateTime','pH total', 'hydrocatSalinity']]

# %%
df1["time"] = pd.to_datetime(df1['DateTime'])
df2["time"] = pd.to_datetime(df2['DateTime'])
# Out:
# /var/folders/9k/5r38tm8d21g6nm3w9rchrd6m0000gn/T/ipykernel_29466/513205946.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["time"] = pd.to_datetime(df1['DateTime'])
# /var/folders/9k/5r38tm8d21g6nm3w9rchrd6m0000gn/T/ipykernel_29466/513205946.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["time"] = pd.to_datetime(df2['DateTime'])

# %%
merged_dataframe = pd.merge_asof(df1, df2, on="time",tolerance = pd.Timedelta("5m"))

# %%
merged_dataframe = merged_dataframe.dropna()
merged_dataframe = merged_dataframe.reset_index(drop=True)
merged_dataframe
# Out:
#                             DateTime_x  pH total  hydrocatSalinity  \
# 0     2021-08-20 16:16:14.800000+00:00  7.880243           29.8311
# 1     2021-08-20 16:21:15.200000+00:00  7.890373           29.8245
# 2     2021-08-20 16:26:14.600000+00:00  7.890361           29.8574
# 3     2021-08-20 16:31:14.800000+00:00  7.890285           29.8153
# 4     2021-08-20 16:36:15.200000+00:00  7.890094           29.8620
# ...                                ...       ...               ...
# 2098  2023-05-01 03:02:03.400000+00:00  8.020383           28.0154
# 2099  2023-05-01 06:02:03.400000+00:00  7.991272           28.5530
# 2100  2023-05-01 09:02:03.400000+00:00  8.020705           28.2610
# 2101         2023-05-01 12:02:04+00:00  8.021757           28.7592
# 2102  2023-05-01 15:02:01.800000+00:00  8.010090           28.4235
#
#                                  time                        DateTime_y  \
# 0    2021-08-20 16:16:14.800000+00:00         2021-08-20 16:12:01+00:00
# 1    2021-08-20 16:21:15.200000+00:00         2021-08-20 16:17:01+00:00
# 2    2021-08-20 16:26:14.600000+00:00         2021-08-20 16:22:01+00:00
# 3    2021-08-20 16:31:14.800000+00:00         2021-08-20 16:27:01+00:00
# 4    2021-08-20 16:36:15.200000+00:00         2021-08-20 16:32:01+00:00
# ...                               ...                               ...
# 2098 2023-05-01 03:02:03.400000+00:00  2023-05-01 03:02:01.800000+00:00
# 2099 2023-05-01 06:02:03.400000+00:00  2023-05-01 06:02:01.800000+00:00
# 2100 2023-05-01 09:02:03.400000+00:00  2023-05-01 09:02:01.800000+00:00
# 2101        2023-05-01 12:02:04+00:00  2023-05-01 12:02:01.800000+00:00
# 2102 2023-05-01 15:02:01.800000+00:00  2023-05-01 15:02:01.800000+00:00
#
#       PARcalibrated
# 0        406.535000
# 1        444.981000
# 2        515.138000
# 3        449.471000
# 4        686.953000
# ...             ...
# 2098      -0.052586
# 2099       6.056120
# 2100     804.532000
# 2101    1963.050000
# 2102    1469.940000
#
# [2103 rows x 6 columns]

# %%
from matplotlib import pyplot as plt
plt.scatter(merged_dataframe['PARcalibrated'],  merged_dataframe['pH total'])

# %%
for i in hydrocat620.index:
    hydrocat620['DateTime'][i] =  pd.Timestamp(hydrocat620['TmStamp'][i])
for i in PAR620.index:
    PAR620['DateTime'][i] =  pd.Timestamp(PAR620['TmStamp'][i])
# Out:
# /var/folders/9k/5r38tm8d21g6nm3w9rchrd6m0000gn/T/ipykernel_29466/4024259061.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hydrocat620['DateTime'][i] =  pd.Timestamp(hydrocat620['TmStamp'][i])
# /var/folders/9k/5r38tm8d21g6nm3w9rchrd6m0000gn/T/ipykernel_29466/4024259061.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PAR620['DateTime'][i] =  pd.Timestamp(PAR620['TmStamp'][i])

# %%
pd.Timestamp(hydrocat620['TmStamp'][1])
# Out:
# Timestamp('2021-05-27 10:40:43.600000+0000', tz='UTC')

# %%
fig, ax = plt.subplots(figsize = [10,10])
ax.plot(PAR620['DateTime'], PAR620['PARcalibrated'])
ax.set_ylim([0,2000])
# Out:
# (0.0, 2000.0)
